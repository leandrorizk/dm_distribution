# %%
#I put this code in my jupyter directory. 
#You probably need to change to dir variable below to point to /data/vxtest/519
#You will also need to change the toutfile to the same location
#The cluster number is ncluster and the set of times
#DTmax is the time interval over which particles left recently which will be followed
#The plot starts at ifile_start
 
import numpy as np
import astropy as ast
import scipy as sc
import matplotlib.pyplot as plt
 

dir = '/data/vxtest/519'
DTmax = 0.4
ncluster = 192
ifile_start = 930
 
plt.rcParams["figure.figsize"] = (16,10)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Time [Gyr]',size='x-large')
ax1.set_ylabel('L - <L> [kpc km/sec]',size='x-large')
 
nskip=1
nplot = int((1330-ifile_start)/nskip + 1)
print("nplot ",nplot)
ifile = ifile_start
toutfile =   dir +'/TOUT' + f'{ifile:04}'
thead = np.fromfile(toutfile,dtype='double',count=1)
Tend = thead[0]
print(ifile,Tend)
nnn = np.fromfile(toutfile,dtype='int32',count=3,offset=8)
nstart = nnn[0]
ntc = nnn[1]
nts = nnn[2]
Toffset = 14.1 - Tend
print(Tend,nstart,ntc,nts,Toffset)
noff = 8 + 3*4
Nco = np.zeros(ntc,dtype='int32')
outid = []
ctout = []
for i in range(ntc):
    Nco[i] = np.fromfile(toutfile,dtype='int32',count=1,offset=noff)
    noff += 4
    readoutN = np.fromfile(toutfile,dtype='int32',count=Nco[i],offset=noff)
    outid.append(readoutN)
    noff += 4*Nco[i]
    readoutT= np.fromfile(toutfile,dtype='double',count=Nco[i],offset=noff)
    ctout.append(readoutT)
    noff += 8*Nco[i]

cplot = ctout[ncluster] < DTmax
print("Cluster",ncluster,Tend,DTmax,np.sum(cplot))
ptime = []
Ltime = []
for i in range(nplot):
    ifile = ifile_start + nskip*i
    filename =   dir+'/snapshot_' + f'{ifile:04}'
    hd = np.fromfile(filename,dtype='int32',count=7)
    nd = hd[2]
    ns = hd[5]
    nc = hd[3]
    nb = hd[4]
    head = np.fromfile(filename,dtype='double',count=7,offset=4+6*4)
    time=head[6]
 
    start_d = 0
    start_c = nd
    start_s = nd + nc + nb
    start_b = nd + nc
    block = nd + nc + ns + nb
 
    skipx = 256 + 3*4 + start_b*3*8
    skipv = 256 + 5*4 + (block*3 + start_b*3)*8
    rc = np.fromfile(filename,dtype='double',count=3,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3,offset=skipv)
    xh = rc[0]
    yh = rc[1]
    zh = rc[2]
    vxh = vc[0]
    vyh = vc[1]
    vzh = vc[2]
 
    skipx = 256 + 3*4 + start_c*3*8
    skipv = 256 + 5*4 + (block*3 + start_c*3)*8
    skipi = 256 + 7*4 + block*3*2*8 + start_c*4
    rc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipv)
    idc = np.fromfile(filename,dtype='uint32',count=nc,offset=skipi)
    jxc = rc[0::3] - xh
    jyc = rc[1::3] - yh
    jzc = rc[2::3] - zh
 
    jvxc = vc[0::3] - vxh
    jvyc = vc[1::3] - vyh
    jvzc = vc[2::3] - vzh
 
    idc -= nd
    ki = np.zeros(nc,dtype='int32')
    for j in range(nc):
        ix = idc[j]
        ki[ix] = j
 
    rh3 = [xh,yh,zh]
    vh3 = [vxh,vyh,vzh]
 
    #centers unsorted
    jrc3 = np.reshape(rc,(nc,3)) - rh3
    jvc3 = np.reshape(vc,(nc,3)) - vh3
 
    rc3 = jrc3[ki]
    vc3 = jvc3[ki]
 
    #stars
    skipx = 256 + 3*4 + start_s*3*8
    skipv = 256 + 5*4 + block*3*8 + start_s*3*8 #skip over r, and dm+c v's
    skipi = 256 + 7*4 + block*3*2*8 + start_s*4 #skip over r and v and dm+c id
    skipc = 256 + 9*4 + block*(2*3*8+4) + start_s*4 #skip over r, v and id and dm+c ic
 
    rs= np.fromfile(filename,dtype='double',count=3*ns,offset=skipx)
    vs = np.fromfile(filename,dtype='double',count=3*ns,offset=skipv)
    ids = np.fromfile(filename,dtype='uint32',count=ns,offset=skipi)
    jics = np.fromfile(filename,dtype='uint32',count=ns,offset=skipc)
 
    jrs3 = np.reshape(rs,(ns,3)) - rh3
    jvs3 = np.reshape(vs,(ns,3)) - vh3
 
    ids -= nd + nc + nb
    ki = np.zeros(ns,dtype='int32')
    for j in range(ns):
        ix = ids[j]
        ki[ix] = j
 
    rs3 = jrs3[ki]
    vs3 = jvs3[ki]
    ics = jics[ki]
 
    dsm = np.linalg.norm(rs3,axis=1)
    vsm  =np.linalg.norm(vs3,axis=1)
 
    Ls3 = np.cross(rs3,vs3)
    Lsm = np.linalg.norm(Ls3,axis=1)
    vts = Lsm/dsm
    vrs = (rs3*vs3).sum(axis=1)/dsm
 
    dcm = np.linalg.norm(rc3,axis=1)
    vcm  =np.linalg.norm(vc3,axis=1)
 
    Lc3 = np.cross(rc3,vc3)
    Lcm = np.linalg.norm(Lc3,axis=1)
    vtc = Lcm/dcm
    vrc =  (rc3*vc3).sum(axis=1)/dcm
 
    lon = np.arctan2(rs3[:,1],rs3[:,0])
    lat = np.arcsin(rs3[:,2]/dsm)
    Lsz = np.abs(Ls3[:,2])
 
    lonc = np.arctan2(rc3[:,1],rc3[:,0])
    latc = np.arcsin(rc3[:,2]/dcm)
    Lcz = np.abs(Lc3[:,2])
    tempYc3 = -np.cross(rc3,np.cross(rc3,vc3))
    normYc3 = np.sqrt((tempYc3 ** 2).sum(-1))[..., np.newaxis]
    Yc3 = tempYc3 / normYc3
 
    rotx = np.sum(rc3[ics] * rs3,axis=1)/dcm[ics]
    roty = np.sum(Yc3[ics] * rs3,axis=1)
    rotz = np.sum(Lc3[ics] * rs3,axis=1)/Lcm[ics]
    rotlen = np.sqrt(rotx**2 + roty**2 + rotz**2)
    rotlon = np.arctan2(roty,rotx)
    rotlat = np.arcsin(rotz/rotlen)
    if i == 0:
        inLs30 = Ls3[outid[ncluster]]
   
    rotvx = np.sum(rc3[ics] * vs3,axis=1)/dcm[ics]
    rotvy = np.sum(Yc3[ics] * vs3,axis=1)
    rotvz = np.sum(Lc3[ics] * vs3,axis=1)/Lcm[ics]
 
    rotcx = np.sum(rc3 * rc3,axis=1)/dcm
    rotcy = np.sum(Yc3 * rc3,axis=1)
    rotcz = np.sum(Lc3 * rc3,axis=1)/Lcm
 
    rotclen = np.sqrt(rotcx**2 + rotcy**2 + rotcz**2)
    rotclon = np.arctan2(rotcy,rotcx)
    rotclat = np.arcsin(rotcz/rotclen)
 
    inLs3 = Ls3[outid[ncluster]]
    Lsav = np.mean(np.linalg.norm(inLs3,axis=1))
    dLs = inLs3[cplot] - inLs30[cplot] #- Lc3[ncluster]
    dLm = np.linalg.norm(dLs,axis=1)
    dLav = np.median(dLm)
    dLst = np.var(dLm)
    dLm -= dLav
    atime = np.full_like(dLm,time)
    ptime.append(atime)
    Ltime.append(dLm)
    ax1.scatter(time,Lsav/40,color='black',s=2) #L scaling
    indsm = dsm[outid[ncluster]]
    dmedian = np.median(indsm[cplot])
    ax1.scatter(time,(dmedian-200),color='red',s=2) #L scaling
    print(i,ifile,f'{time:.2f} {dLav:.1f} {np.sqrt(dLst):.1f} {Lsav:.1f} {Lcm[ncluster]:.1f} {dmedian:.1f}')
    #plotoff += plotinc
# Out:
# nplot  401
# 930 10.099999999153177
# 10.099999999153177 930 271 4718000 4.000000000846823
# Cluster 192 10.099999999153177 0.4 122
# 0 930 10.10 0.0 0.0 2522.6 3344.4 30.2
# 1 931 10.11 26.0 1.4 2525.0 3321.7 30.2
# 2 932 10.12 64.1 1.3 2525.6 3290.5 30.1
# 3 933 10.13 96.6 1.1 2527.1 3257.1 30.0
# 4 934 10.14 123.4 1.6 2527.4 3222.5 29.9
# 5 935 10.15 169.5 2.5 2527.3 3177.9 29.7
# 6 936 10.16 206.7 3.6 2526.1 3139.0 29.4
# 7 937 10.17 252.1 4.4 2523.0 3094.9 29.2
# 8 938 10.18 323.9 5.7 2516.2 3024.3 28.8
# 9 939 10.19 365.5 7.0 2513.8 2984.1 28.4
# 10 940 10.20 425.1 8.8 2510.9 2932.2 27.9
# 11 941 10.21 534.9 12.0 2504.9 2829.0 27.4
# 12 942 10.22 664.7 15.0 2506.0 2745.6 26.8
# 13 943 10.23 764.0 17.8 2537.6 2748.9 26.0
# 14 944 10.24 801.2 17.9 2608.0 2904.1 25.1
# 15 945 10.25 758.2 15.0 2658.5 3090.3 24.2
# 16 946 10.26 664.8 10.7 2673.3 3238.6 23.1
# 17 947 10.27 585.9 7.6 2671.6 3341.0 22.0
# 18 948 10.28 531.7 6.6 2666.5 3396.9 21.0
# 19 949 10.29 491.3 7.3 2663.8 3435.0 19.9
# 20 950 10.30 473.2 9.0 2665.2 3476.0 18.9
# 21 951 10.31 468.0 10.6 2665.5 3499.7 17.9
# 22 952 10.32 467.4 11.2 2669.1 3530.4 17.0
# 23 953 10.33 471.9 10.8 2673.2 3548.2 16.2
# 24 954 10.34 475.8 10.7 2675.7 3559.1 15.5
# 25 955 10.35 479.7 10.2 2677.1 3567.9 14.9
# 26 956 10.36 485.3 9.7 2680.7 3577.1 14.6
# 27 957 10.37 485.2 9.4 2682.8 3572.5 14.5
# 28 958 10.38 479.5 9.3 2682.7 3560.4 14.6
# 29 959 10.39 472.3 9.4 2684.0 3549.0 15.0
# 30 960 10.40 455.1 9.3 2681.7 3520.5 15.5
# 45 975 10.55 290.3 7.1 2632.1 3272.1 29.2
# 46 976 10.56 275.0 7.0 2629.8 3265.1 29.8
# 47 977 10.57 274.4 7.2 2628.3 3262.2 30.5
# 48 978 10.58 255.2 7.1 2626.3 3265.0 31.1
# 49 979 10.59 227.9 7.3 2624.6 3272.9 31.6
# 50 980 10.60 220.0 7.6 2623.5 3271.8 32.1
# 51 981 10.61 201.5 8.3 2626.7 3298.3 32.5
# 52 982 10.62 165.6 9.4 2631.1 3330.1 32.9
# 53 983 10.63 160.2 9.7 2629.2 3327.0 33.2
# 54 984 10.64 145.0 9.6 2626.7 3326.0 33.5
# 55 985 10.65 135.0 10.6 2629.2 3347.9 33.7
# 56 986 10.66 130.4 11.5 2630.4 3360.0 33.9
# 57 987 10.67 123.9 12.8 2632.8 3382.1 34.0
# 58 988 10.68 133.2 15.0 2636.0 3410.7 34.1
# 59 989 10.69 136.8 16.3 2636.8 3421.9 34.1
# 60 990 10.70 147.9 18.0 2639.7 3442.9 34.1
# 61 991 10.71 164.6 19.9 2642.1 3469.9 34.0
# 62 992 10.72 194.3 21.1 2645.2 3510.0 33.9
# 63 993 10.73 225.1 22.1 2648.8 3539.4 33.7
# 64 994 10.74 241.7 22.9 2649.6 3559.4 33.5
# 65 995 10.75 274.8 24.8 2654.3 3596.2 33.2
# 66 996 10.76 321.5 26.1 2660.3 3646.6 32.9
# 67 997 10.77 341.4 28.4 2662.7 3672.5 32.6
# 68 998 10.78 373.9 30.0 2666.7 3705.5 32.2
# 69 999 10.79 444.7 29.7 2675.2 3776.9 31.7
# 70 1000 10.80 487.5 29.6 2679.8 3825.3 31.3
# 71 1001 10.81 522.7 30.5 2685.0 3856.3 30.7
# 72 1002 10.82 580.8 30.2 2694.2 3918.9 30.2
# 73 1003 10.83 622.0 30.2 2700.0 3954.9 29.6
# 74 1004 10.84 643.1 31.3 2702.7 3979.6 28.9
# 75 1005 10.85 700.7 31.7 2712.7 4037.5 28.3
# 76 1006 10.86 737.7 33.0 2720.0 4076.4 27.6
# 77 1007 10.87 768.4 32.2 2725.2 4104.7 26.8
# 78 1008 10.88 798.8 28.7 2729.3 4132.4 26.1
# 79 1009 10.89 824.7 24.5 2733.6 4156.8 25.3
# 80 1010 10.90 831.0 19.4 2735.0 4158.5 24.6
# 81 1011 10.91 842.2 15.2 2737.2 4164.3 23.8
# 82 1012 10.92 851.3 15.3 2740.1 4170.6 23.1
# 83 1013 10.93 857.8 17.1 2742.9 4171.6 22.3
# 84 1014 10.94 857.0 20.3 2743.1 4160.2 21.7
# 85 1015 10.95 845.5 24.8 2741.6 4135.4 21.0
# 86 1016 10.96 811.4 27.5 2737.6 4101.4 20.5
# 87 1017 10.97 783.2 29.0 2735.5 4076.9 20.0
# 88 1018 10.98 751.0 28.7 2731.9 4049.2 19.7
# 89 1019 10.99 709.2 27.1 2726.0 4011.5 19.4
# 90 1020 11.00 673.9 24.6 2720.8 3976.3 19.2
# 91 1021 11.01 650.2 22.2 2717.8 3958.1 19.1
# 92 1022 11.02 631.0 18.9 2714.8 3941.3 19.1
# 93 1023 11.03 608.9 15.6 2711.5 3921.9 19.1
# 94 1024 11.04 598.6 12.5 2708.9 3915.7 19.3
# 95 1025 11.05 594.3 12.2 2708.6 3914.2 19.5
# 96 1026 11.06 591.9 13.8 2709.1 3916.4 19.8
# 97 1027 11.07 608.3 16.3 2712.5 3938.6 20.1
# 98 1028 11.08 625.3 20.4 2717.3 3955.0 20.5
# 99 1029 11.09 634.1 25.9 2718.5 3971.5 21.0
# 100 1030 11.10 652.9 30.5 2721.1 3996.6 21.5
# 101 1031 11.11 677.8 34.1 2724.4 4021.7 22.0
# 102 1032 11.12 692.6 37.5 2724.5 4044.6 22.5
# 103 1033 11.13 710.5 40.6 2725.1 4067.5 23.1
# 104 1034 11.14 726.2 40.9 2729.0 4082.0 23.6
# 105 1035 11.15 758.6 42.5 2732.7 4116.0 24.2
# 106 1036 11.16 788.0 42.8 2736.1 4146.2 24.8
# 107 1037 11.17 813.5 43.3 2736.7 4170.4 25.3
# 108 1038 11.18 831.7 43.2 2736.1 4191.8 25.9
# 109 1039 11.19 838.1 39.7 2737.1 4194.7 26.5
# 110 1040 11.20 882.3 36.2 2742.6 4231.1 27.0
# 111 1041 11.21 903.0 33.0 2745.7 4249.9 27.5
# 112 1042 11.22 921.4 30.4 2749.2 4264.8 28.1
# 113 1043 11.23 927.8 26.4 2751.4 4268.1 28.6
# 114 1044 11.24 946.2 24.9 2751.4 4283.4 29.1
# 115 1045 11.25 976.1 23.2 2754.2 4305.3 29.6
# 116 1046 11.26 991.4 20.4 2757.5 4320.3 30.0
# 117 1047 11.27 1000.3 18.0 2757.0 4323.5 30.5
# 118 1048 11.28 1001.9 15.8 2754.5 4324.4 30.9
# 119 1049 11.29 1005.9 12.6 2757.7 4321.8 31.3
# 120 1050 11.30 1001.7 11.0 2758.6 4309.1 31.7
# 121 1051 11.31 991.1 11.4 2754.6 4304.0 32.1
# 122 1052 11.32 999.4 10.3 2755.7 4305.0 32.4
# 123 1053 11.33 998.6 9.9 2757.6 4298.8 32.7
# 124 1054 11.34 998.6 10.3 2757.0 4295.7 33.0
# 125 1055 11.35 993.3 10.7 2752.9 4283.4 33.3
# 126 1056 11.36 986.4 11.5 2749.3 4271.7 33.5
# 127 1057 11.37 968.7 12.7 2746.9 4249.7 33.7
# 128 1058 11.38 944.4 13.9 2742.9 4218.2 33.9
# 129 1059 11.39 949.5 15.5 2742.0 4217.3 34.0
# 130 1060 11.40 953.0 16.8 2742.6 4213.7 34.1
# 131 1061 11.41 926.7 17.4 2738.1 4185.1 34.2
# 132 1062 11.42 910.2 18.5 2733.6 4165.6 34.2
# 133 1063 11.43 904.5 19.8 2732.7 4151.3 34.3
# 134 1064 11.44 887.7 21.4 2730.6 4125.1 34.2
# 135 1065 11.45 862.2 22.6 2726.4 4089.9 34.2
# 136 1066 11.46 822.8 23.3 2722.5 4050.2 34.1
# 137 1067 11.47 800.1 23.2 2719.5 4022.7 34.1
# 138 1068 11.48 789.2 24.0 2715.0 3998.1 33.9
# 139 1069 11.49 764.9 24.9 2710.8 3959.2 33.8
# 140 1070 11.50 746.1 25.2 2709.1 3931.6 33.6
# 141 1071 11.51 733.4 25.0 2706.6 3913.7 33.3
# 142 1072 11.52 729.7 25.5 2706.3 3905.8 33.1
# 143 1073 11.53 703.0 24.8 2698.7 3859.0 32.8
# 144 1074 11.54 689.2 24.7 2692.7 3827.7 32.4
# 145 1075 11.55 678.7 24.4 2690.2 3807.2 32.1
# 146 1076 11.56 674.2 24.6 2691.1 3798.7 31.6
# 147 1077 11.57 672.0 24.3 2689.8 3785.2 31.2
# 148 1078 11.58 661.5 23.7 2686.0 3770.0 30.7
# 149 1079 11.59 641.2 23.5 2676.9 3738.2 30.2
# 150 1080 11.60 634.7 23.2 2671.1 3723.5 29.6
# 151 1081 11.61 648.5 23.2 2673.2 3726.2 29.0
# 152 1082 11.62 659.4 24.0 2674.4 3737.7 28.4
# 153 1083 11.63 661.1 24.2 2674.2 3736.4 27.8
# 154 1084 11.64 656.8 23.6 2671.1 3729.5 27.1
# 155 1085 11.65 668.1 23.1 2677.2 3748.8 26.4
# 156 1086 11.66 693.1 23.2 2691.0 3786.1 25.7
# 157 1087 11.67 699.2 22.3 2695.4 3801.0 24.9
# 158 1088 11.68 695.6 20.2 2695.0 3805.0 24.2
# 159 1089 11.69 698.3 18.9 2696.1 3810.6 23.4
# 160 1090 11.70 713.0 17.6 2702.3 3835.9 22.7
# 161 1091 11.71 711.2 16.8 2699.2 3840.1 21.9
# 162 1092 11.72 717.9 17.8 2698.8 3853.1 21.1
# 163 1093 11.73 734.8 19.7 2704.1 3875.4 20.4
# 164 1094 11.74 749.8 21.7 2704.5 3895.0 19.6
# 165 1095 11.75 762.6 22.2 2703.2 3914.0 19.0
# 166 1096 11.76 769.3 26.7 2702.5 3929.1 18.4
# 167 1097 11.77 786.1 29.7 2704.2 3946.0 17.8
# 168 1098 11.78 814.0 27.2 2707.9 3968.9 17.4
# 169 1099 11.79 826.6 23.3 2706.1 3967.8 17.1
# 170 1100 11.80 849.7 19.5 2707.2 3976.2 17.0
# 171 1101 11.81 857.0 17.4 2708.9 3977.1 17.1
# 172 1102 11.82 867.9 16.9 2710.6 3969.2 17.2
# 173 1103 11.83 864.5 17.7 2710.3 3944.3 17.4
# 174 1104 11.84 870.6 19.4 2712.2 3935.5 17.9
# 175 1105 11.85 873.8 21.8 2712.1 3929.9 18.4
# 176 1106 11.86 874.4 25.4 2711.5 3909.5 19.1
# 177 1107 11.87 864.4 27.0 2710.0 3881.7 19.8
# 178 1108 11.88 854.4 27.2 2710.5 3868.8 20.6
# 179 1109 11.89 848.5 26.3 2709.6 3855.0 21.4
# 180 1110 11.90 830.6 25.3 2709.5 3837.3 22.3
# 181 1111 11.91 819.8 25.6 2707.7 3813.8 23.1
# 182 1112 11.92 815.4 25.4 2705.0 3797.5 24.0
# 183 1113 11.93 802.8 25.2 2701.8 3773.3 24.8
# 184 1114 11.94 786.9 24.6 2699.9 3754.5 25.7
# 185 1115 11.95 786.6 23.9 2699.0 3754.6 26.5
# 186 1116 11.96 783.0 23.9 2696.3 3745.7 27.2
# 187 1117 11.97 775.6 23.5 2693.8 3734.0 28.0
# 188 1118 11.98 769.8 22.9 2692.9 3731.2 28.7
# 189 1119 11.99 773.9 22.6 2693.1 3736.6 29.4
# 190 1120 12.00 759.8 23.3 2686.9 3708.6 30.0
# 191 1121 12.01 755.7 23.0 2686.1 3701.0 30.6
# 192 1122 12.02 757.3 22.4 2687.9 3709.5 31.2
# 193 1123 12.03 750.5 22.2 2687.0 3697.4 31.7
# 194 1124 12.04 747.0 22.9 2685.9 3680.7 32.2
# 195 1125 12.05 755.3 23.0 2689.1 3689.6 32.6
# 196 1126 12.06 744.0 21.6 2687.8 3683.1 33.0
# 197 1127 12.07 736.4 21.2 2687.3 3674.7 33.4
# 198 1128 12.08 732.5 21.9 2687.6 3660.0 33.7
# 199 1129 12.09 733.3 21.3 2689.5 3661.1 33.9
# 200 1130 12.10 726.2 20.8 2688.1 3651.7 34.1
# 201 1131 12.11 728.5 20.7 2690.9 3655.0 34.3
# 202 1132 12.12 734.1 20.5 2693.4 3667.8 34.3
# 203 1133 12.13 742.2 20.4 2696.5 3682.5 34.4
# 204 1134 12.14 739.3 20.5 2695.2 3680.1 34.4
# 205 1135 12.15 731.4 20.7 2692.2 3663.2 34.4
# 206 1136 12.16 735.5 21.2 2692.4 3668.5 34.3
# 207 1137 12.17 746.0 21.7 2695.3 3684.7 34.2
# 208 1138 12.18 750.5 22.2 2698.7 3697.0 34.0
# 209 1139 12.19 764.3 23.7 2701.1 3712.1 33.7
# 210 1140 12.20 774.1 24.7 2705.8 3733.6 33.5
# 211 1141 12.21 775.3 25.2 2705.6 3746.6 33.1
# 212 1142 12.22 787.5 27.1 2706.9 3757.3 32.8
# 213 1143 12.23 793.7 28.2 2706.6 3761.5 32.4
# 214 1144 12.24 808.2 29.3 2704.7 3767.8 31.9
# 215 1145 12.25 837.3 31.3 2708.5 3795.3 31.4
# 216 1146 12.26 845.5 32.6 2711.0 3813.0 30.8
# 217 1147 12.27 854.9 33.1 2720.2 3849.1 30.2
# 218 1148 12.28 862.5 34.6 2721.6 3858.4 29.6
# 219 1149 12.29 881.6 36.5 2721.3 3873.6 28.9
# 220 1150 12.30 909.4 37.4 2726.0 3906.8 28.2
# 221 1151 12.31 936.2 38.3 2730.3 3933.8 27.5
# 222 1152 12.32 947.3 40.3 2730.3 3946.8 26.7
# 223 1153 12.33 967.7 40.9 2731.7 3964.2 25.9
# 224 1154 12.34 989.7 38.9 2734.6 3984.9 25.0
# 225 1155 12.35 1005.9 36.3 2738.3 4006.0 24.2
# 226 1156 12.36 1018.5 32.5 2738.8 4012.9 23.3
# 227 1157 12.37 1028.4 29.5 2737.8 4010.9 22.5
# 228 1158 12.38 1056.0 26.6 2739.5 4012.5 21.6
# 229 1159 12.39 1059.3 24.3 2740.4 4012.5 20.8
# 230 1160 12.40 1058.7 22.5 2739.9 3999.0 20.0
# 231 1161 12.41 1062.7 22.9 2739.9 3980.6 19.3
# 232 1162 12.42 1064.6 23.9 2742.3 3972.1 18.7
# 233 1163 12.43 1057.9 26.0 2744.0 3956.5 18.1
# 234 1164 12.44 1051.7 27.8 2744.9 3937.0 17.7
# 235 1165 12.45 1048.8 29.0 2745.8 3923.9 17.3
# 236 1166 12.46 1030.2 29.7 2744.3 3895.9 17.2
# 237 1167 12.47 1001.3 28.8 2740.8 3861.1 17.3
# 238 1168 12.48 996.2 28.5 2740.5 3853.1 17.3
# 239 1169 12.49 991.6 27.2 2739.6 3852.4 17.4
# 240 1170 12.50 974.2 25.7 2737.1 3835.0 17.7
# 241 1171 12.51 964.2 25.0 2734.1 3824.2 18.2
# 242 1172 12.52 961.8 24.8 2732.1 3829.1 18.7
# 243 1173 12.53 969.7 25.3 2731.2 3847.4 19.3
# 244 1174 12.54 972.6 26.5 2729.5 3848.4 20.0
# 245 1175 12.55 972.6 28.8 2727.1 3848.8 20.7
# 246 1176 12.56 978.6 30.7 2726.4 3863.0 21.4
# 247 1177 12.57 993.8 32.5 2726.7 3885.2 22.1
# 248 1178 12.58 1014.1 34.2 2726.8 3915.0 22.8
# 249 1179 12.59 1030.3 35.9 2726.9 3929.3 23.6
# 250 1180 12.60 1027.4 35.6 2727.8 3938.3 24.3
# 251 1181 12.61 1044.7 36.6 2729.6 3966.9 25.0
# 252 1182 12.62 1065.9 38.1 2728.4 3964.2 25.7
# 253 1183 12.63 1085.5 39.7 2730.4 3986.0 26.4
# 254 1184 12.64 1103.0 40.3 2732.8 4010.4 27.1
# 255 1185 12.65 1131.3 40.8 2735.4 4041.8 27.7
# 256 1186 12.66 1158.3 41.6 2737.5 4067.3 28.3
# 257 1187 12.67 1168.4 40.7 2737.7 4069.9 28.9
# 258 1188 12.68 1192.7 40.5 2740.3 4092.6 29.4
# 259 1189 12.69 1219.9 40.2 2742.9 4112.3 29.9
# 260 1190 12.70 1239.7 39.6 2746.5 4128.6 30.4
# 261 1191 12.71 1249.5 37.6 2749.6 4143.1 30.8
# 262 1192 12.72 1258.5 35.9 2749.0 4139.3 31.2
# 263 1193 12.73 1276.9 35.7 2750.4 4147.4 31.6
# 264 1194 12.74 1300.9 34.8 2753.7 4169.3 31.9
# 265 1195 12.75 1299.5 33.7 2754.9 4171.5 32.2
# 266 1196 12.76 1319.0 33.3 2758.2 4187.1 32.5
# 267 1197 12.77 1348.2 33.0 2757.5 4190.8 32.7
# 268 1198 12.78 1363.1 32.2 2759.2 4197.2 32.8
# 269 1199 12.79 1341.7 31.5 2761.5 4194.8 33.0
# 270 1200 12.80 1347.3 30.8 2763.2 4204.1 33.1
# 271 1201 12.81 1361.0 30.1 2762.2 4202.0 33.1
# 272 1202 12.82 1361.7 29.6 2764.2 4202.8 33.1
# 273 1203 12.83 1367.4 29.1 2767.5 4216.7 33.1
# 274 1204 12.84 1374.7 28.6 2762.8 4192.0 33.1
# 275 1205 12.85 1380.9 28.1 2761.5 4184.3 33.0
# 276 1206 12.86 1371.8 28.0 2761.9 4181.5 32.8
# 277 1207 12.87 1369.6 27.7 2761.8 4178.6 32.7
# 278 1208 12.88 1373.2 27.8 2759.5 4167.4 32.5
# 279 1209 12.89 1363.8 27.8 2761.0 4173.4 32.3
# 280 1210 12.90 1360.2 27.7 2763.6 4172.4 32.0
# 281 1211 12.91 1379.0 28.0 2765.5 4179.1 31.7
# 282 1212 12.92 1376.4 30.1 2760.1 4158.1 31.3
# 283 1213 12.93 1356.9 30.2 2757.1 4131.3 30.9
# 284 1214 12.94 1340.3 31.4 2754.2 4099.1 30.5
# 285 1215 12.95 1347.7 32.4 2754.9 4096.7 30.1
# 286 1216 12.96 1352.5 33.4 2755.6 4097.1 29.6
# 287 1217 12.97 1322.0 33.9 2751.2 4061.9 29.1
# 288 1218 12.98 1305.8 35.3 2748.3 4030.9 28.5
# 289 1219 12.99 1290.9 36.1 2745.0 4004.0 28.0
# 290 1220 13.00 1281.9 36.7 2745.8 3995.5 27.4
# 291 1221 13.01 1257.6 36.6 2742.2 3966.1 26.7
# 292 1222 13.02 1240.4 36.5 2740.3 3942.1 26.1
# 293 1223 13.03 1236.7 36.0 2739.8 3937.7 25.4
# 294 1224 13.04 1240.7 35.5 2742.2 3949.6 24.7
# 295 1225 13.05 1228.8 35.2 2739.5 3932.1 24.0
# 296 1226 13.06 1210.4 33.9 2736.6 3907.5 23.3
# 297 1227 13.07 1207.3 32.4 2737.3 3909.6 22.6
# 298 1228 13.08 1206.6 31.2 2736.6 3914.4 21.9
# 299 1229 13.09 1199.9 30.6 2734.2 3899.2 21.2
# 300 1230 13.10 1195.5 30.5 2732.2 3896.5 20.5
# 301 1231 13.11 1202.0 30.8 2732.4 3903.8 19.8
# 302 1232 13.12 1216.1 32.1 2735.8 3918.0 19.2
# 303 1233 13.13 1231.3 34.4 2737.4 3935.9 18.7
# 304 1234 13.14 1232.8 36.9 2734.3 3956.7 18.2
# 305 1235 13.15 1244.3 39.5 2735.0 3976.6 17.9
# 306 1236 13.16 1264.2 42.7 2736.6 3989.6 17.6
# 307 1237 13.17 1283.8 44.4 2737.0 4015.2 17.5
# 308 1238 13.18 1300.3 44.0 2737.3 4047.0 17.5
# 309 1239 13.19 1326.1 39.4 2740.2 4059.5 17.5
# 310 1240 13.20 1347.3 34.8 2742.8 4056.0 17.6
# 311 1241 13.21 1353.3 31.2 2743.6 4054.9 17.9
# 312 1242 13.22 1358.6 29.8 2744.1 4060.7 18.4
# 313 1243 13.23 1368.1 29.7 2744.9 4058.5 18.9
# 314 1244 13.24 1371.9 29.8 2745.6 4050.1 19.5
# 315 1245 13.25 1365.3 30.4 2745.8 4039.1 20.2
# 316 1246 13.26 1355.1 31.3 2746.0 4025.4 20.9
# 317 1247 13.27 1359.0 31.8 2745.9 4024.5 21.6
# 318 1248 13.28 1351.2 32.7 2745.5 4009.6 22.4
# 319 1249 13.29 1337.0 34.0 2744.2 3989.0 23.2
# 320 1250 13.30 1325.5 35.3 2742.6 3957.6 24.0
# 321 1251 13.31 1304.7 35.1 2742.0 3947.2 24.8
# 322 1252 13.32 1282.7 35.2 2740.3 3921.8 25.6
# 323 1253 13.33 1266.6 36.3 2736.6 3887.1 26.4
# 324 1254 13.34 1263.8 36.9 2734.4 3874.4 27.1
# 325 1255 13.35 1260.4 36.3 2734.0 3877.1 27.8
# 326 1256 13.36 1245.6 35.7 2731.5 3858.4 28.5
# 327 1257 13.37 1225.3 35.6 2726.8 3823.5 29.1
# 328 1258 13.38 1213.3 35.3 2724.0 3804.5 29.7
# 329 1259 13.39 1202.0 34.6 2721.4 3792.6 30.2
# 330 1260 13.40 1185.2 34.7 2715.7 3754.4 30.7
# 331 1261 13.41 1177.7 34.1 2713.5 3741.0 31.2
# 332 1262 13.42 1177.6 33.8 2712.8 3742.1 31.6
# 333 1263 13.43 1169.0 33.3 2709.7 3720.8 31.9
# 334 1264 13.44 1153.1 33.2 2703.3 3691.3 32.2
# 335 1265 13.45 1150.7 32.5 2701.9 3689.7 32.5
# 336 1266 13.46 1146.2 31.7 2699.2 3675.5 32.7
# 337 1267 13.47 1132.8 31.4 2692.4 3637.7 32.9
# 338 1268 13.48 1123.1 31.0 2686.7 3612.4 33.0
# 339 1269 13.49 1118.9 30.4 2682.3 3587.8 33.1
# 340 1270 13.50 1113.7 30.1 2679.0 3572.6 33.1
# 341 1271 13.51 1112.6 29.9 2677.4 3565.4 33.0
# 342 1272 13.52 1118.2 30.2 2676.4 3560.2 32.9
# 343 1273 13.53 1114.8 30.0 2674.9 3557.5 32.7
# 344 1274 13.54 1104.0 29.9 2667.5 3532.1 32.5
# 345 1275 13.55 1100.4 30.1 2662.8 3516.0 32.2
# 346 1276 13.56 1103.5 30.3 2660.0 3509.5 31.9
# 347 1277 13.57 1113.5 30.8 2660.0 3522.7 31.5
# 348 1278 13.58 1120.8 31.6 2660.5 3541.2 31.0
# 349 1279 13.59 1121.5 32.1 2658.9 3535.9 30.5
# 350 1280 13.60 1128.7 33.1 2658.4 3548.2 29.8
# 351 1281 13.61 1139.4 34.1 2660.3 3571.6 29.2
# 352 1282 13.62 1153.7 35.2 2661.1 3583.3 28.4
# 353 1283 13.63 1168.5 36.1 2662.6 3601.3 27.6
# 354 1284 13.64 1180.7 37.1 2665.8 3627.5 26.8
# 355 1285 13.65 1198.9 37.9 2670.2 3657.9 25.9
# 356 1286 13.66 1223.7 39.1 2676.3 3696.8 25.0
# 357 1287 13.67 1237.5 40.0 2679.5 3724.8 24.0
# 358 1288 13.68 1243.8 40.4 2683.2 3751.1 23.0
# 359 1289 13.69 1263.7 40.7 2688.7 3787.1 22.0
# 360 1290 13.70 1282.5 40.5 2692.9 3820.2 21.0
# 361 1291 13.71 1280.6 40.8 2694.7 3848.6 20.0
# 362 1292 13.72 1285.9 38.0 2697.8 3868.6 19.0
# 363 1293 13.73 1293.5 33.5 2702.9 3879.0 18.1
# 364 1294 13.74 1298.4 31.7 2705.5 3873.2 17.2
# 365 1295 13.75 1292.4 32.8 2706.8 3870.6 16.4
# 366 1296 13.76 1267.2 33.9 2706.3 3865.1 15.7
# 367 1297 13.77 1240.7 34.3 2704.9 3861.2 15.3
# 368 1298 13.78 1219.5 33.6 2703.5 3862.3 15.2
# 369 1299 13.79 1202.8 33.3 2702.1 3862.6 15.2
# 370 1300 13.80 1192.5 35.7 2701.4 3869.6 15.1
# 371 1301 13.81 1180.7 40.8 2700.1 3877.8 15.4
# 372 1302 13.82 1170.3 43.9 2694.1 3870.3 15.9
# 373 1303 13.83 1165.4 46.5 2691.0 3870.4 16.6
# 374 1304 13.84 1165.6 51.1 2690.3 3880.7 17.4
# 375 1305 13.85 1169.4 54.5 2692.2 3896.6 18.3
# 376 1306 13.86 1176.6 58.2 2694.2 3921.2 19.2
# 377 1307 13.87 1184.1 62.1 2696.8 3938.4 20.2
# 378 1308 13.88 1186.2 64.1 2698.3 3948.3 21.3
# 379 1309 13.89 1181.8 64.7 2700.4 3951.7 22.3
# 380 1310 13.90 1189.2 66.4 2705.0 3973.2 23.3
# 381 1311 13.91 1206.3 69.1 2714.4 4020.9 24.3
# 382 1312 13.92 1218.6 70.3 2715.5 4029.6 25.2
# 383 1313 13.93 1223.1 70.9 2717.8 4039.2 26.1
# 384 1314 13.94 1236.4 71.5 2721.9 4064.5 27.0
# 385 1315 13.95 1248.3 72.0 2726.4 4094.6 27.8
# 386 1316 13.96 1262.3 73.6 2730.6 4115.9 28.6
# 387 1317 13.97 1280.3 75.1 2734.5 4145.3 29.3
# 388 1318 13.98 1303.8 77.5 2743.3 4196.7 30.0
# 389 1319 13.99 1312.8 77.9 2745.4 4213.5 30.6
# 390 1320 14.00 1322.6 80.0 2747.7 4230.5 31.2
# 391 1321 14.01 1343.2 86.9 2752.6 4265.9 31.7
# 392 1322 14.02 1358.8 90.1 2756.4 4290.0 32.2
# 393 1323 14.03 1365.2 89.4 2759.5 4312.7 32.7
# 394 1324 14.04 1394.1 83.9 2763.1 4333.9 33.1
# 395 1325 14.05 1429.9 80.3 2767.2 4370.7 33.4
# 396 1326 14.06 1447.4 80.4 2769.8 4404.9 33.7
# 397 1327 14.07 1462.8 81.9 2773.6 4434.5 33.9
# 398 1328 14.08 1502.2 82.0 2778.7 4474.5 34.1
# 399 1329 14.09 1529.6 81.1 2781.7 4506.2 34.3
# 400 1330 14.10 1544.4 79.6 2783.3 4524.1 34.4

# %%
encounter_time_1 = 11.12
encounter_time_2 = 11.26
encounter_time_3 = 11.78
encounter_time_4 = 12.53
encounter_time_5 = 13.35
encounter_time_6 = 13.50
encounter_time_7 = 13.68

# %%
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gyr]', size=18)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=18)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gyr]', size=18)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=18)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

plt.axvspan(encounter_time_3 - 0.04, encounter_time_3 + 0.04,
            color='silver', alpha=0.5, label='Close encounter with DM subhalo')

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations.pdf', format='pdf', bbox_inches='tight')
plt.show()
