# %%
#I put this code in my jupyter directory. 
#You probably need to change to dir variable below to point to /data/vxtest/519
#You will also need to change the toutfile to the same location
#The cluster number is ncluster and the set of times
#DTmax is the time interval over which particles left recently which will be followed
#The plot starts at ifile_start
 
import numpy as np
import astropy as ast
import scipy as sc
import matplotlib.pyplot as plt
 

dir = '/data/vxtest/519'
DTmax = 0.4
ncluster = 190
ifile_start = 930
 
plt.rcParams["figure.figsize"] = (16,10)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Time [Gyr]',size='x-large')
ax1.set_ylabel('L - <L> [kpc km/sec]',size='x-large')
 
nskip=1
nplot = int((1330-ifile_start)/nskip + 1)
print("nplot ",nplot)
ifile = ifile_start
toutfile =   dir +'/TOUT' + f'{ifile:04}'
thead = np.fromfile(toutfile,dtype='double',count=1)
Tend = thead[0]
print(ifile,Tend)
nnn = np.fromfile(toutfile,dtype='int32',count=3,offset=8)
nstart = nnn[0]
ntc = nnn[1]
nts = nnn[2]
Toffset = 14.1 - Tend
print(Tend,nstart,ntc,nts,Toffset)
noff = 8 + 3*4
Nco = np.zeros(ntc,dtype='int32')
outid = []
ctout = []
for i in range(ntc):
    Nco[i] = np.fromfile(toutfile,dtype='int32',count=1,offset=noff)
    noff += 4
    readoutN = np.fromfile(toutfile,dtype='int32',count=Nco[i],offset=noff)
    outid.append(readoutN)
    noff += 4*Nco[i]
    readoutT= np.fromfile(toutfile,dtype='double',count=Nco[i],offset=noff)
    ctout.append(readoutT)
    noff += 8*Nco[i]

cplot = ctout[ncluster] < DTmax
print("Cluster",ncluster,Tend,DTmax,np.sum(cplot))
ptime = []
Ltime = []
for i in range(nplot):
    ifile = ifile_start + nskip*i
    filename =   dir+'/snapshot_' + f'{ifile:04}'
    hd = np.fromfile(filename,dtype='int32',count=7)
    nd = hd[2]
    ns = hd[5]
    nc = hd[3]
    nb = hd[4]
    head = np.fromfile(filename,dtype='double',count=7,offset=4+6*4)
    time=head[6]
 
    start_d = 0
    start_c = nd
    start_s = nd + nc + nb
    start_b = nd + nc
    block = nd + nc + ns + nb
 
    skipx = 256 + 3*4 + start_b*3*8
    skipv = 256 + 5*4 + (block*3 + start_b*3)*8
    rc = np.fromfile(filename,dtype='double',count=3,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3,offset=skipv)
    xh = rc[0]
    yh = rc[1]
    zh = rc[2]
    vxh = vc[0]
    vyh = vc[1]
    vzh = vc[2]
 
    skipx = 256 + 3*4 + start_c*3*8
    skipv = 256 + 5*4 + (block*3 + start_c*3)*8
    skipi = 256 + 7*4 + block*3*2*8 + start_c*4
    rc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipv)
    idc = np.fromfile(filename,dtype='uint32',count=nc,offset=skipi)
    jxc = rc[0::3] - xh
    jyc = rc[1::3] - yh
    jzc = rc[2::3] - zh
 
    jvxc = vc[0::3] - vxh
    jvyc = vc[1::3] - vyh
    jvzc = vc[2::3] - vzh
 
    idc -= nd
    ki = np.zeros(nc,dtype='int32')
    for j in range(nc):
        ix = idc[j]
        ki[ix] = j
 
    rh3 = [xh,yh,zh]
    vh3 = [vxh,vyh,vzh]
 
    #centers unsorted
    jrc3 = np.reshape(rc,(nc,3)) - rh3
    jvc3 = np.reshape(vc,(nc,3)) - vh3
 
    rc3 = jrc3[ki]
    vc3 = jvc3[ki]
 
    #stars
    skipx = 256 + 3*4 + start_s*3*8
    skipv = 256 + 5*4 + block*3*8 + start_s*3*8 #skip over r, and dm+c v's
    skipi = 256 + 7*4 + block*3*2*8 + start_s*4 #skip over r and v and dm+c id
    skipc = 256 + 9*4 + block*(2*3*8+4) + start_s*4 #skip over r, v and id and dm+c ic
 
    rs= np.fromfile(filename,dtype='double',count=3*ns,offset=skipx)
    vs = np.fromfile(filename,dtype='double',count=3*ns,offset=skipv)
    ids = np.fromfile(filename,dtype='uint32',count=ns,offset=skipi)
    jics = np.fromfile(filename,dtype='uint32',count=ns,offset=skipc)
 
    jrs3 = np.reshape(rs,(ns,3)) - rh3
    jvs3 = np.reshape(vs,(ns,3)) - vh3
 
    ids -= nd + nc + nb
    ki = np.zeros(ns,dtype='int32')
    for j in range(ns):
        ix = ids[j]
        ki[ix] = j
 
    rs3 = jrs3[ki]
    vs3 = jvs3[ki]
    ics = jics[ki]
 
    dsm = np.linalg.norm(rs3,axis=1)
    vsm  =np.linalg.norm(vs3,axis=1)
 
    Ls3 = np.cross(rs3,vs3)
    Lsm = np.linalg.norm(Ls3,axis=1)
    vts = Lsm/dsm
    vrs = (rs3*vs3).sum(axis=1)/dsm
 
    dcm = np.linalg.norm(rc3,axis=1)
    vcm  =np.linalg.norm(vc3,axis=1)
 
    Lc3 = np.cross(rc3,vc3)
    Lcm = np.linalg.norm(Lc3,axis=1)
    vtc = Lcm/dcm
    vrc =  (rc3*vc3).sum(axis=1)/dcm
 
    lon = np.arctan2(rs3[:,1],rs3[:,0])
    lat = np.arcsin(rs3[:,2]/dsm)
    Lsz = np.abs(Ls3[:,2])
 
    lonc = np.arctan2(rc3[:,1],rc3[:,0])
    latc = np.arcsin(rc3[:,2]/dcm)
    Lcz = np.abs(Lc3[:,2])
    tempYc3 = -np.cross(rc3,np.cross(rc3,vc3))
    normYc3 = np.sqrt((tempYc3 ** 2).sum(-1))[..., np.newaxis]
    Yc3 = tempYc3 / normYc3
 
    rotx = np.sum(rc3[ics] * rs3,axis=1)/dcm[ics]
    roty = np.sum(Yc3[ics] * rs3,axis=1)
    rotz = np.sum(Lc3[ics] * rs3,axis=1)/Lcm[ics]
    rotlen = np.sqrt(rotx**2 + roty**2 + rotz**2)
    rotlon = np.arctan2(roty,rotx)
    rotlat = np.arcsin(rotz/rotlen)
    if i == 0:
        inLs30 = Ls3[outid[ncluster]]
   
    rotvx = np.sum(rc3[ics] * vs3,axis=1)/dcm[ics]
    rotvy = np.sum(Yc3[ics] * vs3,axis=1)
    rotvz = np.sum(Lc3[ics] * vs3,axis=1)/Lcm[ics]
 
    rotcx = np.sum(rc3 * rc3,axis=1)/dcm
    rotcy = np.sum(Yc3 * rc3,axis=1)
    rotcz = np.sum(Lc3 * rc3,axis=1)/Lcm
 
    rotclen = np.sqrt(rotcx**2 + rotcy**2 + rotcz**2)
    rotclon = np.arctan2(rotcy,rotcx)
    rotclat = np.arcsin(rotcz/rotclen)
 
    inLs3 = Ls3[outid[ncluster]]
    Lsav = np.mean(np.linalg.norm(inLs3,axis=1))
    dLs = inLs3[cplot] - inLs30[cplot] #- Lc3[ncluster]
    dLm = np.linalg.norm(dLs,axis=1)
    dLav = np.median(dLm)
    dLst = np.var(dLm)
    dLm -= dLav
    atime = np.full_like(dLm,time)
    ptime.append(atime)
    Ltime.append(dLm)
    ax1.scatter(time,Lsav/40,color='black',s=2) #L scaling
    indsm = dsm[outid[ncluster]]
    dmedian = np.median(indsm[cplot])
    ax1.scatter(time,(dmedian-200),color='red',s=2) #L scaling
    print(i,ifile,f'{time:.2f} {dLav:.1f} {np.sqrt(dLst):.1f} {Lsav:.1f} {Lcm[ncluster]:.1f} {dmedian:.1f}')
    #plotoff += plotinc
# Out:
# nplot  401
# 930 10.099999999153177
# 10.099999999153177 930 271 4718000 4.000000000846823
# Cluster 190 10.099999999153177 0.4 130
# 0 930 10.10 0.0 0.0 2278.8 2712.4 22.7
# 1 931 10.11 36.3 0.7 2284.6 2743.2 22.6
# 2 932 10.12 58.8 1.4 2293.0 2770.6 22.6
# 3 933 10.13 88.4 1.6 2302.5 2801.1 22.4
# 4 934 10.14 136.0 2.4 2311.8 2848.4 22.3
# 5 935 10.15 172.6 3.6 2327.4 2883.0 22.1
# 6 936 10.16 218.2 4.4 2339.7 2929.4 21.8
# 7 937 10.17 270.3 5.9 2347.4 2979.7 21.5
# 8 938 10.18 319.6 8.7 2355.4 3029.2 21.2
# 9 939 10.19 365.4 11.3 2357.4 3070.9 20.9
# 10 940 10.20 406.6 13.6 2361.9 3107.9 20.6
# 11 941 10.21 453.7 17.5 2373.3 3144.2 20.2
# 12 942 10.22 517.8 21.8 2385.7 3186.2 19.9
# 13 943 10.23 562.3 24.7 2410.6 3175.3 19.6
# 14 944 10.24 610.2 24.2 2444.6 3106.7 19.4
# 15 945 10.25 628.0 22.5 2451.1 3052.8 19.0
# 16 946 10.26 601.2 21.1 2425.6 3049.8 18.6
# 17 947 10.27 589.8 18.9 2390.5 3107.5 18.0
# 18 948 10.28 637.6 13.1 2365.8 3225.9 17.4
# 19 949 10.29 734.4 44.0 2350.0 3316.7 16.7
# 20 950 10.30 717.7 69.1 2333.6 3291.5 16.0
# 21 951 10.31 662.8 79.5 2315.9 3230.7 15.5
# 22 952 10.32 591.8 78.0 2302.5 3153.8 15.1
# 23 953 10.33 534.5 71.9 2290.1 3086.9 14.8
# 24 954 10.34 498.7 65.0 2276.5 3036.2 14.7
# 25 955 10.35 477.9 59.4 2261.9 3005.2 14.6
# 26 956 10.36 454.1 53.8 2253.3 2971.6 14.7
# 27 957 10.37 453.8 49.1 2246.1 2955.2 14.8
# 367 1297 13.77 2543.7 42.9 2187.7 2941.0 19.9
# 368 1298 13.78 2529.4 44.6 2182.7 2962.6 20.0
# 369 1299 13.79 2516.1 48.2 2181.1 2962.6 19.7
# 370 1300 13.80 2496.5 53.9 2180.9 2953.0 20.4
# 371 1301 13.81 2485.2 64.5 2181.3 2973.2 21.0
# 372 1302 13.82 2483.6 86.7 2185.7 3020.5 21.5
# 373 1303 13.83 2479.6 123.9 2192.1 3096.2 21.9
# 374 1304 13.84 2478.2 175.9 2197.6 3206.3 22.3
# 375 1305 13.85 2478.3 207.6 2203.5 3351.3 22.6
# 376 1306 13.86 2477.9 218.6 2207.2 3490.0 23.0
# 377 1307 13.87 2483.6 222.4 2212.3 3591.5 23.5
# 378 1308 13.88 2507.2 226.0 2216.7 3676.6 23.9
# 379 1309 13.89 2540.4 230.6 2222.7 3734.7 24.3
# 380 1310 13.90 2560.8 231.7 2227.9 3761.2 24.4
# 381 1311 13.91 2573.0 229.8 2235.1 3759.4 24.2
# 382 1312 13.92 2597.0 225.0 2237.2 3756.5 24.0
# 383 1313 13.93 2631.1 222.3 2241.3 3750.3 23.6
# 384 1314 13.94 2655.2 217.7 2243.4 3742.5 23.1
# 385 1315 13.95 2682.1 213.4 2245.8 3733.4 22.6
# 386 1316 13.96 2710.2 206.9 2250.2 3703.2 22.1
# 387 1317 13.97 2734.5 200.6 2253.9 3671.9 21.5
# 388 1318 13.98 2757.8 198.5 2258.1 3649.6 21.0
# 389 1319 13.99 2778.9 199.8 2260.1 3635.6 20.4
# 390 1320 14.00 2808.0 200.6 2263.7 3603.0 20.1
# 391 1321 14.01 2830.5 199.4 2267.0 3563.2 19.9
# 392 1322 14.02 2847.2 199.4 2268.7 3533.4 19.7
# 393 1323 14.03 2866.6 204.4 2269.4 3517.8 20.1
# 394 1324 14.04 2875.2 202.5 2270.6 3492.8 19.6
# 395 1325 14.05 2883.1 200.8 2272.4 3466.9 19.1
# 396 1326 14.06 2894.7 205.3 2274.2 3449.5 18.6
# 397 1327 14.07 2895.3 211.9 2276.0 3435.7 18.8
# 398 1328 14.08 2885.4 212.9 2276.4 3444.6 18.4
# 399 1329 14.09 2874.8 217.5 2276.6 3463.7 18.1
# 400 1330 14.10 2862.4 224.2 2276.9 3477.3 17.8

# %%
encounter_time_1 = 11.12
encounter_time_2 = 11.26
encounter_time_3 = 11.78
encounter_time_4 = 12.53
encounter_time_5 = 13.35
encounter_time_6 = 13.50
encounter_time_7 = 13.68

# %%
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gyr]', size=18)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=18)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gyr]', size=18)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=18)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

plt.axvspan(encounter_time_3 - 0.04, encounter_time_3 + 0.04,
            color='silver', alpha=0.5, label='Close encounter with DM subhalo')

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations.pdf', format='pdf', bbox_inches='tight')
plt.show()
