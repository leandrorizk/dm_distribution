# %%
#I put this code in my jupyter directory. 
#You probably need to change to dir variable below to point to /data/vxtest/519
#You will also need to change the toutfile to the same location
#The cluster number is ncluster and the set of times
#DTmax is the time interval over which particles left recently which will be followed
#The plot starts at ifile_start
 
import numpy as np
import astropy as ast
import scipy as sc
import matplotlib.pyplot as plt
 

dir = '/data/vxtest/519'
DTmax = 0.4
ncluster = 208
ifile_start = 930
 
plt.rcParams["figure.figsize"] = (16,10)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Time [Gyr]',size='x-large')
ax1.set_ylabel('L - <L> [kpc km/sec]',size='x-large')
 
nskip=1
nplot = int((1330-ifile_start)/nskip + 1)
print("nplot ",nplot)
ifile = ifile_start
toutfile =   dir +'/TOUT' + f'{ifile:04}'
thead = np.fromfile(toutfile,dtype='double',count=1)
Tend = thead[0]
print(ifile,Tend)
nnn = np.fromfile(toutfile,dtype='int32',count=3,offset=8)
nstart = nnn[0]
ntc = nnn[1]
nts = nnn[2]
Toffset = 14.1 - Tend
print(Tend,nstart,ntc,nts,Toffset)
noff = 8 + 3*4
Nco = np.zeros(ntc,dtype='int32')
outid = []
ctout = []
for i in range(ntc):
    Nco[i] = np.fromfile(toutfile,dtype='int32',count=1,offset=noff)
    noff += 4
    readoutN = np.fromfile(toutfile,dtype='int32',count=Nco[i],offset=noff)
    outid.append(readoutN)
    noff += 4*Nco[i]
    readoutT= np.fromfile(toutfile,dtype='double',count=Nco[i],offset=noff)
    ctout.append(readoutT)
    noff += 8*Nco[i]

cplot = ctout[ncluster] < DTmax
print("Cluster",ncluster,Tend,DTmax,np.sum(cplot))
ptime = []
Ltime = []
for i in range(nplot):
    ifile = ifile_start + nskip*i
    filename =   dir+'/snapshot_' + f'{ifile:04}'
    hd = np.fromfile(filename,dtype='int32',count=7)
    nd = hd[2]
    ns = hd[5]
    nc = hd[3]
    nb = hd[4]
    head = np.fromfile(filename,dtype='double',count=7,offset=4+6*4)
    time=head[6]
 
    start_d = 0
    start_c = nd
    start_s = nd + nc + nb
    start_b = nd + nc
    block = nd + nc + ns + nb
 
    skipx = 256 + 3*4 + start_b*3*8
    skipv = 256 + 5*4 + (block*3 + start_b*3)*8
    rc = np.fromfile(filename,dtype='double',count=3,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3,offset=skipv)
    xh = rc[0]
    yh = rc[1]
    zh = rc[2]
    vxh = vc[0]
    vyh = vc[1]
    vzh = vc[2]
 
    skipx = 256 + 3*4 + start_c*3*8
    skipv = 256 + 5*4 + (block*3 + start_c*3)*8
    skipi = 256 + 7*4 + block*3*2*8 + start_c*4
    rc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipv)
    idc = np.fromfile(filename,dtype='uint32',count=nc,offset=skipi)
    jxc = rc[0::3] - xh
    jyc = rc[1::3] - yh
    jzc = rc[2::3] - zh
 
    jvxc = vc[0::3] - vxh
    jvyc = vc[1::3] - vyh
    jvzc = vc[2::3] - vzh
 
    idc -= nd
    ki = np.zeros(nc,dtype='int32')
    for j in range(nc):
        ix = idc[j]
        ki[ix] = j
 
    rh3 = [xh,yh,zh]
    vh3 = [vxh,vyh,vzh]
 
    #centers unsorted
    jrc3 = np.reshape(rc,(nc,3)) - rh3
    jvc3 = np.reshape(vc,(nc,3)) - vh3
 
    rc3 = jrc3[ki]
    vc3 = jvc3[ki]
 
    #stars
    skipx = 256 + 3*4 + start_s*3*8
    skipv = 256 + 5*4 + block*3*8 + start_s*3*8 #skip over r, and dm+c v's
    skipi = 256 + 7*4 + block*3*2*8 + start_s*4 #skip over r and v and dm+c id
    skipc = 256 + 9*4 + block*(2*3*8+4) + start_s*4 #skip over r, v and id and dm+c ic
 
    rs= np.fromfile(filename,dtype='double',count=3*ns,offset=skipx)
    vs = np.fromfile(filename,dtype='double',count=3*ns,offset=skipv)
    ids = np.fromfile(filename,dtype='uint32',count=ns,offset=skipi)
    jics = np.fromfile(filename,dtype='uint32',count=ns,offset=skipc)
 
    jrs3 = np.reshape(rs,(ns,3)) - rh3
    jvs3 = np.reshape(vs,(ns,3)) - vh3
 
    ids -= nd + nc + nb
    ki = np.zeros(ns,dtype='int32')
    for j in range(ns):
        ix = ids[j]
        ki[ix] = j
 
    rs3 = jrs3[ki]
    vs3 = jvs3[ki]
    ics = jics[ki]
 
    dsm = np.linalg.norm(rs3,axis=1)
    vsm  =np.linalg.norm(vs3,axis=1)
 
    Ls3 = np.cross(rs3,vs3)
    Lsm = np.linalg.norm(Ls3,axis=1)
    vts = Lsm/dsm
    vrs = (rs3*vs3).sum(axis=1)/dsm
 
    dcm = np.linalg.norm(rc3,axis=1)
    vcm  =np.linalg.norm(vc3,axis=1)
 
    Lc3 = np.cross(rc3,vc3)
    Lcm = np.linalg.norm(Lc3,axis=1)
    vtc = Lcm/dcm
    vrc =  (rc3*vc3).sum(axis=1)/dcm
 
    lon = np.arctan2(rs3[:,1],rs3[:,0])
    lat = np.arcsin(rs3[:,2]/dsm)
    Lsz = np.abs(Ls3[:,2])
 
    lonc = np.arctan2(rc3[:,1],rc3[:,0])
    latc = np.arcsin(rc3[:,2]/dcm)
    Lcz = np.abs(Lc3[:,2])
    tempYc3 = -np.cross(rc3,np.cross(rc3,vc3))
    normYc3 = np.sqrt((tempYc3 ** 2).sum(-1))[..., np.newaxis]
    Yc3 = tempYc3 / normYc3
 
    rotx = np.sum(rc3[ics] * rs3,axis=1)/dcm[ics]
    roty = np.sum(Yc3[ics] * rs3,axis=1)
    rotz = np.sum(Lc3[ics] * rs3,axis=1)/Lcm[ics]
    rotlen = np.sqrt(rotx**2 + roty**2 + rotz**2)
    rotlon = np.arctan2(roty,rotx)
    rotlat = np.arcsin(rotz/rotlen)
    if i == 0:
        inLs30 = Ls3[outid[ncluster]]
   
    rotvx = np.sum(rc3[ics] * vs3,axis=1)/dcm[ics]
    rotvy = np.sum(Yc3[ics] * vs3,axis=1)
    rotvz = np.sum(Lc3[ics] * vs3,axis=1)/Lcm[ics]
 
    rotcx = np.sum(rc3 * rc3,axis=1)/dcm
    rotcy = np.sum(Yc3 * rc3,axis=1)
    rotcz = np.sum(Lc3 * rc3,axis=1)/Lcm
 
    rotclen = np.sqrt(rotcx**2 + rotcy**2 + rotcz**2)
    rotclon = np.arctan2(rotcy,rotcx)
    rotclat = np.arcsin(rotcz/rotclen)
 
    inLs3 = Ls3[outid[ncluster]]
    Lsav = np.mean(np.linalg.norm(inLs3,axis=1))
    dLs = inLs3[cplot] - inLs30[cplot] #- Lc3[ncluster]
    dLm = np.linalg.norm(dLs,axis=1)
    dLav = np.median(dLm)
    dLst = np.var(dLm)
    dLm -= dLav
    atime = np.full_like(dLm,time)
    ptime.append(atime)
    Ltime.append(dLm)
    ax1.scatter(time,Lsav/40,color='black',s=2) #L scaling
    indsm = dsm[outid[ncluster]]
    dmedian = np.median(indsm[cplot])
    ax1.scatter(time,(dmedian-200),color='red',s=2) #L scaling
    print(i,ifile,f'{time:.2f} {dLav:.1f} {np.sqrt(dLst):.1f} {Lsav:.1f} {Lcm[ncluster]:.1f} {dmedian:.1f}')
    #plotoff += plotinc

ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_ylim(-200,200)
 
for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
#plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)
# Out:
# nplot  401
# 930 10.099999999153177
# 10.099999999153177 930 271 4718000 4.000000000846823
# Cluster 208 10.099999999153177 0.4 224
# 0 930 10.10 0.0 0.0 2794.2 3069.0 27.2
# 1 931 10.11 44.0 0.9 2817.6 3107.6 27.0
# 2 932 10.12 71.7 1.6 2835.6 3139.8 26.8
# 3 933 10.13 109.7 2.4 2857.5 3177.2 26.5
# 4 934 10.14 161.6 3.4 2887.5 3223.1 26.2
# 5 935 10.15 216.8 4.6 2921.1 3282.0 25.9
# 6 936 10.16 267.1 5.7 2950.4 3332.9 25.5
# 7 937 10.17 330.1 7.3 2987.3 3390.7 25.0
# 8 938 10.18 414.9 9.1 3037.6 3478.1 24.6
# 9 939 10.19 480.3 10.6 3075.8 3538.3 24.1
# 10 940 10.20 567.3 12.4 3127.2 3627.0 23.7
# 11 941 10.21 703.6 15.4 3207.8 3753.5 23.2
# 12 942 10.22 872.5 18.8 3308.4 3923.0 22.7
# 13 943 10.23 1063.9 20.9 3424.1 4119.7 22.2
# 14 944 10.24 1234.2 20.6 3531.7 4296.5 21.6
# 15 945 10.25 1284.9 18.1 3566.7 4341.6 21.0
# 16 946 10.26 1247.4 14.5 3542.8 4307.1 20.4
# 17 947 10.27 1195.0 11.5 3506.2 4256.7 19.8
# 18 948 10.28 1178.2 13.7 3483.1 4236.8 19.2
# 19 949 10.29 1200.1 22.2 3473.1 4257.4 18.6
# 20 950 10.30 1212.7 44.1 3454.4 4259.0 18.0
# 21 951 10.31 1150.3 67.7 3408.5 4171.7 17.7
# 22 952 10.32 1053.0 75.5 3359.8 4070.1 17.5
# 23 953 10.33 961.4 75.3 3316.7 3979.5 17.5
# 24 954 10.34 879.3 74.1 3278.8 3897.4 17.7
# 25 955 10.35 809.2 67.4 3250.0 3835.0 18.0
# 26 956 10.36 756.5 62.9 3226.4 3784.4 18.3
# 27 957 10.37 710.5 57.8 3206.8 3742.9 18.8
# 28 958 10.38 680.3 52.8 3196.3 3714.3 19.3
# 29 959 10.39 658.9 49.3 3187.4 3693.6 19.8
# 30 960 10.40 649.5 46.5 3184.9 3683.5 20.4
# 31 961 10.41 650.5 43.8 3188.8 3690.6 21.0
# 32 962 10.42 663.1 41.1 3199.2 3699.5 21.6
# 33 963 10.43 674.6 39.6 3207.5 3706.1 22.3
# 34 964 10.44 688.6 38.0 3221.3 3726.1 22.9
# 35 965 10.45 698.9 36.3 3230.6 3739.1 23.5
# 36 966 10.46 718.3 34.8 3243.5 3760.1 24.1
# 37 967 10.47 736.0 34.0 3255.6 3779.8 24.7
# 38 968 10.48 748.1 33.3 3264.2 3793.9 25.3
# 39 969 10.49 784.5 32.5 3289.6 3832.2 25.9
# 40 970 10.50 833.2 32.5 3320.1 3876.7 26.4
# 41 971 10.51 863.7 32.1 3340.9 3908.8 27.0
# 42 972 10.52 884.5 31.6 3355.6 3937.6 27.5
# 43 973 10.53 906.4 32.2 3370.2 3966.0 28.0
# 44 974 10.54 927.6 33.2 3381.7 3981.3 28.5
# 45 975 10.55 953.6 34.3 3397.5 4006.4 28.9
# 46 976 10.56 978.9 35.4 3413.9 4030.7 29.4
# 47 977 10.57 1021.4 36.7 3441.6 4074.6 29.8
# 48 978 10.58 1040.5 38.0 3451.7 4089.1 30.2
# 49 979 10.59 1049.7 39.2 3454.5 4096.7 30.5
# 50 980 10.60 1066.3 41.2 3462.3 4110.1 30.9
# 51 981 10.61 1075.9 41.8 3467.2 4111.8 31.2
# 52 982 10.62 1076.5 41.0 3464.8 4116.0 31.5
# 53 983 10.63 1109.2 43.8 3480.4 4142.5 31.8
# 54 984 10.64 1121.1 46.6 3481.2 4144.8 32.0
# 55 985 10.65 1131.1 47.4 3483.7 4151.7 32.2
# 56 986 10.66 1158.9 49.3 3495.2 4171.4 32.4
# 57 987 10.67 1176.6 49.8 3498.5 4179.2 32.6
# 58 988 10.68 1180.2 50.3 3495.2 4174.9 32.8
# 59 989 10.69 1186.8 52.2 3490.7 4175.4 32.9
# 60 990 10.70 1213.0 53.9 3494.6 4186.3 33.0
# 61 991 10.71 1220.0 55.8 3491.5 4182.3 33.0
# 62 992 10.72 1208.8 56.7 3478.4 4174.7 33.1
# 63 993 10.73 1216.3 58.3 3472.6 4154.7 33.0
# 64 994 10.74 1219.1 60.9 3462.1 4145.9 33.0
# 65 995 10.75 1242.1 63.5 3465.9 4153.5 32.9
# 66 996 10.76 1256.9 64.4 3466.5 4155.6 32.9
# 67 997 10.77 1267.8 68.2 3464.8 4156.6 32.7
# 68 998 10.78 1281.0 70.6 3460.2 4149.4 32.6
# 69 999 10.79 1306.3 69.3 3456.2 4142.8 32.4
# 70 1000 10.80 1307.1 70.1 3446.3 4129.4 32.2
# 71 1001 10.81 1314.6 73.0 3440.5 4113.0 31.9
# 72 1002 10.82 1343.0 74.3 3439.4 4115.4 31.7
# 73 1003 10.83 1347.1 74.3 3426.5 4089.4 31.4
# 74 1004 10.84 1327.1 73.8 3406.5 4059.4 31.0
# 75 1005 10.85 1347.4 75.3 3409.8 4061.1 30.6
# 76 1006 10.86 1353.5 77.3 3398.1 4048.6 30.2
# 77 1007 10.87 1350.8 78.3 3384.0 4026.8 29.8
# 78 1008 10.88 1351.9 77.8 3371.7 4004.3 29.4
# 79 1009 10.89 1354.6 79.7 3358.1 3979.5 28.9
# 80 1010 10.90 1346.7 80.7 3341.5 3954.0 28.4
# 81 1011 10.91 1355.5 81.2 3335.7 3934.1 27.8
# 82 1012 10.92 1369.0 82.4 3327.6 3915.5 27.3
# 83 1013 10.93 1379.6 83.2 3310.2 3886.6 26.7
# 84 1014 10.94 1408.6 81.9 3301.7 3866.7 26.1
# 85 1015 10.95 1446.2 81.6 3313.5 3876.5 25.5
# 86 1016 10.96 1452.5 81.7 3318.3 3878.5 24.8
# 87 1017 10.97 1455.6 83.2 3317.6 3874.7 24.1
# 88 1018 10.98 1452.0 83.2 3313.5 3861.8 23.5
# 89 1019 10.99 1442.1 81.5 3310.7 3849.7 22.8
# 90 1020 11.00 1436.3 79.8 3308.9 3838.9 22.1
# 91 1021 11.01 1436.9 79.5 3309.3 3829.9 21.4
# 92 1022 11.02 1433.9 77.9 3308.4 3820.7 20.8
# 93 1023 11.03 1435.4 75.9 3313.8 3815.6 20.2
# 94 1024 11.04 1427.0 71.0 3315.5 3808.8 19.7
# 95 1025 11.05 1426.3 67.9 3319.5 3810.1 19.2
# 96 1026 11.06 1425.9 63.9 3323.2 3812.7 18.8
# 97 1027 11.07 1420.1 58.6 3324.7 3809.4 18.4
# 98 1028 11.08 1420.1 54.5 3329.2 3814.3 18.2
# 99 1029 11.09 1432.0 48.2 3343.9 3834.9 18.1
# 100 1030 11.10 1443.9 41.9 3356.3 3855.0 18.0
# 101 1031 11.11 1455.4 36.1 3365.0 3870.4 18.1
# 102 1032 11.12 1481.6 31.4 3376.4 3894.4 18.4
# 103 1033 11.13 1510.1 28.7 3388.0 3919.5 18.6
# 104 1034 11.14 1518.1 28.7 3382.8 3926.2 19.0
# 105 1035 11.15 1540.0 28.5 3390.1 3944.8 19.4
# 106 1036 11.16 1562.5 28.1 3389.1 3952.3 20.0
# 107 1037 11.17 1597.3 29.0 3391.0 3965.4 20.6
# 108 1038 11.18 1631.1 31.5 3388.5 3975.5 21.3
# 109 1039 11.19 1637.2 35.4 3371.9 3962.2 22.0
# 110 1040 11.20 1664.5 37.4 3377.3 3976.8 22.8
# 111 1041 11.21 1680.0 40.0 3369.0 3963.1 23.5
# 112 1042 11.22 1695.1 42.3 3361.5 3953.6 24.3
# 113 1043 11.23 1705.3 43.9 3346.1 3926.2 25.1
# 114 1044 11.24 1730.8 47.9 3338.9 3924.8 25.8
# 115 1045 11.25 1762.1 51.2 3340.9 3924.2 26.6
# 116 1046 11.26 1781.1 52.6 3337.7 3913.2 27.3
# 117 1047 11.27 1790.9 55.9 3326.0 3892.3 28.0
# 118 1048 11.28 1794.6 59.2 3309.0 3870.2 28.7
# 119 1049 11.29 1807.0 59.4 3309.0 3866.0 29.3
# 120 1050 11.30 1814.4 59.8 3304.1 3851.2 29.9
# 121 1051 11.31 1823.0 61.0 3283.1 3811.5 30.5
# 122 1052 11.32 1848.7 62.0 3283.4 3810.0 31.0
# 123 1053 11.33 1871.8 61.8 3290.0 3818.1 31.5
# 124 1054 11.34 1881.8 62.6 3288.7 3812.7 32.0
# 125 1055 11.35 1888.6 63.6 3270.6 3785.4 32.4
# 126 1056 11.36 1891.4 64.1 3258.6 3768.9 32.7
# 127 1057 11.37 1910.4 64.2 3255.3 3751.7 33.0
# 128 1058 11.38 1915.5 63.6 3254.0 3750.8 33.3
# 129 1059 11.39 1928.8 64.9 3256.4 3752.8 33.5
# 130 1060 11.40 1955.7 66.9 3261.0 3754.8 33.7
# 131 1061 11.41 1968.4 66.7 3254.0 3743.1 33.8
# 132 1062 11.42 1969.1 66.3 3249.6 3732.4 33.9
# 133 1063 11.43 1986.4 67.8 3249.4 3733.8 34.0
# 134 1064 11.44 2002.6 68.4 3260.3 3748.0 34.0
# 135 1065 11.45 2011.6 68.1 3266.1 3754.1 33.9
# 136 1066 11.46 2031.6 68.1 3278.4 3771.0 33.8
# 154 1084 11.64 2026.4 74.3 3262.5 3661.8 25.0
# 155 1085 11.65 2016.4 71.6 3259.0 3650.1 24.2
# 156 1086 11.66 1997.9 70.0 3246.9 3622.8 23.4
# 157 1087 11.67 1993.0 66.7 3246.3 3615.7 22.6
# 158 1088 11.68 1997.1 63.2 3253.1 3630.4 21.8
# 159 1089 11.69 2000.3 57.0 3256.6 3638.3 21.0
# 160 1090 11.70 2001.2 50.1 3259.9 3636.9 20.2
# 161 1091 11.71 2020.8 44.3 3265.3 3653.4 19.4
# 162 1092 11.72 2042.1 38.5 3275.4 3676.5 18.7
# 163 1093 11.73 2051.8 34.1 3276.8 3680.4 18.0
# 164 1094 11.74 2072.1 31.5 3279.2 3695.6 17.4
# 165 1095 11.75 2102.0 30.2 3282.9 3719.3 17.0
# 166 1096 11.76 2135.8 30.1 3285.9 3739.5 16.7
# 167 1097 11.77 2152.4 30.9 3283.7 3739.5 16.6
# 168 1098 11.78 2170.7 32.3 3284.5 3739.8 16.6
# 169 1099 11.79 2194.7 37.1 3277.1 3725.6 16.4
# 170 1100 11.80 2225.8 44.3 3276.0 3726.2 16.4
# 171 1101 11.81 2252.3 50.4 3275.3 3715.0 16.7
# 172 1102 11.82 2270.8 56.6 3273.6 3706.1 17.2
# 173 1103 11.83 2282.4 61.7 3269.9 3689.8 17.8
# 174 1104 11.84 2299.1 68.6 3269.2 3683.7 18.5
# 175 1105 11.85 2313.5 77.4 3261.3 3672.4 19.2
# 176 1106 11.86 2316.4 82.3 3256.0 3661.1 20.0
# 177 1107 11.87 2318.0 85.8 3252.3 3653.4 20.8
# 178 1108 11.88 2326.7 90.8 3251.5 3649.0 21.7
# 179 1109 11.89 2328.0 94.9 3245.0 3636.7 22.5
# 180 1110 11.90 2338.2 98.3 3251.1 3643.1 23.3
# 181 1111 11.91 2337.8 97.8 3254.9 3645.3 24.2
# 182 1112 11.92 2330.9 96.8 3251.2 3633.1 25.0
# 183 1113 11.93 2329.5 95.2 3254.6 3636.8 25.7
# 184 1114 11.94 2335.4 96.0 3261.4 3643.8 26.5
# 185 1115 11.95 2330.1 96.3 3254.8 3633.4 27.2
# 186 1116 11.96 2328.5 94.0 3254.7 3633.4 27.8
# 187 1117 11.97 2327.9 92.1 3257.5 3636.8 28.5
# 188 1118 11.98 2327.9 92.9 3255.7 3631.5 29.1
# 189 1119 11.99 2320.2 90.9 3247.0 3618.9 29.6
# 190 1120 12.00 2333.0 82.9 3263.4 3631.0 30.1
# 191 1121 12.01 2333.7 79.2 3266.4 3643.1 30.6
# 192 1122 12.02 2326.3 78.7 3258.3 3629.6 31.1
# 193 1123 12.03 2335.0 73.0 3267.7 3639.2 31.5
# 194 1124 12.04 2349.8 63.5 3277.9 3651.0 31.8
# 195 1125 12.05 2343.9 58.4 3265.5 3631.9 32.0
# 196 1126 12.06 2350.0 58.0 3274.4 3644.0 32.3
# 197 1127 12.07 2365.1 53.5 3287.8 3667.0 32.6
# 198 1128 12.08 2388.4 44.3 3295.4 3680.3 32.8
# 199 1129 12.09 2391.9 41.5 3297.0 3683.3 32.9
# 200 1130 12.10 2409.9 39.2 3310.5 3706.3 33.0
# 201 1131 12.11 2423.9 33.5 3315.2 3713.8 33.0
# 202 1132 12.12 2429.1 29.8 3314.2 3706.1 33.0
# 203 1133 12.13 2440.8 26.7 3323.8 3725.1 32.9
# 204 1134 12.14 2464.8 23.8 3330.5 3737.0 32.8
# 205 1135 12.15 2496.3 21.6 3340.1 3756.3 32.7
# 206 1136 12.16 2511.9 20.7 3345.1 3764.4 32.5
# 207 1137 12.17 2524.2 20.8 3346.5 3773.6 32.2
# 208 1138 12.18 2552.6 22.0 3355.2 3781.4 32.0
# 209 1139 12.19 2568.3 23.6 3363.0 3799.0 31.7
# 210 1140 12.20 2588.0 27.5 3367.7 3804.2 31.3
# 211 1141 12.21 2610.2 30.8 3366.3 3803.4 30.9
# 212 1142 12.22 2635.0 32.1 3374.9 3826.3 30.5
# 213 1143 12.23 2663.9 33.2 3378.9 3834.4 30.0
# 214 1144 12.24 2674.3 34.5 3373.9 3830.7 29.5
# 215 1145 12.25 2692.8 34.2 3380.0 3848.1 28.9
# 216 1146 12.26 2728.1 33.2 3384.1 3863.3 28.3
# 217 1147 12.27 2777.1 33.5 3395.1 3882.9 27.7
# 218 1148 12.28 2814.9 30.3 3397.0 3894.8 27.0
# 219 1149 12.29 2835.3 27.6 3394.3 3894.9 26.4
# 220 1150 12.30 2855.7 27.6 3395.5 3904.0 25.7
# 221 1151 12.31 2877.6 27.8 3396.0 3908.8 24.9
# 222 1152 12.32 2903.8 30.4 3390.5 3912.1 24.2
# 223 1153 12.33 2930.1 37.0 3385.6 3914.6 23.4
# 224 1154 12.34 2952.3 43.8 3383.9 3911.6 22.7
# 225 1155 12.35 2984.7 53.5 3383.6 3910.3 21.9
# 226 1156 12.36 3005.2 60.7 3381.5 3898.9 21.2
# 227 1157 12.37 3018.3 67.2 3376.3 3880.5 20.5
# 228 1158 12.38 3021.9 74.3 3366.6 3857.6 19.9
# 229 1159 12.39 3038.4 84.6 3362.5 3838.7 19.3
# 230 1160 12.40 3044.9 87.9 3363.3 3830.6 18.8
# 231 1161 12.41 3042.8 91.3 3358.3 3808.2 18.4
# 232 1162 12.42 3042.2 100.1 3348.7 3788.1 18.1
# 233 1163 12.43 3043.6 103.1 3347.8 3782.6 18.0
# 234 1164 12.44 3038.0 103.0 3344.2 3769.5 18.1
# 235 1165 12.45 3025.8 100.6 3337.3 3751.6 17.9
# 236 1166 12.46 3022.7 93.6 3343.5 3759.5 17.8
# 237 1167 12.47 3025.6 87.7 3355.6 3774.6 17.7
# 238 1168 12.48 3017.5 77.8 3353.5 3770.2 18.0
# 239 1169 12.49 3010.3 71.2 3349.9 3761.2 18.3
# 240 1170 12.50 3017.4 67.3 3355.3 3784.3 18.7
# 241 1171 12.51 3030.5 57.3 3366.3 3805.4 19.2
# 242 1172 12.52 3037.6 45.7 3373.9 3816.8 19.8
# 243 1173 12.53 3041.7 37.1 3373.8 3819.6 20.4
# 244 1174 12.54 3051.3 33.4 3367.2 3816.8 21.1
# 245 1175 12.55 3068.3 30.4 3371.2 3836.8 21.8
# 246 1176 12.56 3093.1 25.5 3382.7 3855.7 22.4
# 247 1177 12.57 3111.5 23.7 3390.6 3878.2 23.1
# 248 1178 12.58 3116.6 24.6 3386.2 3871.0 23.8
# 249 1179 12.59 3135.0 25.4 3388.8 3883.1 24.5
# 250 1180 12.60 3175.4 28.6 3397.9 3906.1 25.1
# 251 1181 12.61 3201.9 31.4 3406.6 3921.9 25.7
# 252 1182 12.62 3211.0 27.7 3393.8 3909.2 26.4
# 253 1183 12.63 3241.1 26.6 3401.0 3929.2 27.0
# 254 1184 12.64 3272.7 26.9 3406.7 3941.3 27.5
# 255 1185 12.65 3293.1 27.1 3410.4 3953.3 28.1
# 256 1186 12.66 3315.5 24.3 3411.4 3955.4 28.5
# 257 1187 12.67 3338.3 23.4 3404.4 3948.1 29.0
# 258 1188 12.68 3359.2 22.6 3406.0 3949.7 29.4
# 259 1189 12.69 3378.4 20.1 3405.1 3958.2 29.8
# 260 1190 12.70 3412.0 21.0 3408.4 3972.9 30.1
# 261 1191 12.71 3446.8 23.5 3414.8 3974.2 30.3
# 262 1192 12.72 3461.1 25.5 3407.5 3964.0 30.5
# 263 1193 12.73 3478.3 30.3 3402.1 3952.8 30.8
# 264 1194 12.74 3501.8 34.9 3406.8 3965.0 31.0
# 265 1195 12.75 3536.8 40.4 3409.1 3967.9 31.2
# 266 1196 12.76 3563.1 47.7 3410.0 3969.2 31.3
# 267 1197 12.77 3552.3 53.4 3391.8 3931.5 31.4
# 268 1198 12.78 3565.9 59.3 3390.8 3932.8 31.4
# 269 1199 12.79 3617.4 70.0 3400.6 3951.3 31.4
# 270 1200 12.80 3637.9 78.1 3399.7 3946.0 31.3
# 271 1201 12.81 3634.7 82.9 3388.6 3920.3 31.2
# 272 1202 12.82 3659.1 92.5 3389.4 3926.9 31.0
# 273 1203 12.83 3683.0 103.6 3389.4 3927.1 30.8
# 274 1204 12.84 3668.4 104.0 3376.4 3898.7 30.6
# 275 1205 12.85 3670.4 107.6 3372.4 3885.3 30.3
# 276 1206 12.86 3689.9 118.4 3370.7 3883.5 30.0
# 277 1207 12.87 3696.8 126.3 3365.5 3871.8 29.7
# 278 1208 12.88 3690.6 127.3 3361.4 3860.5 29.3
# 279 1209 12.89 3703.1 137.3 3362.4 3860.8 28.9
# 280 1210 12.90 3711.9 147.9 3359.3 3850.8 28.5
# 281 1211 12.91 3697.6 150.0 3350.0 3829.7 28.0
# 282 1212 12.92 3678.6 147.8 3340.0 3801.9 27.5
# 283 1213 12.93 3682.8 149.3 3342.3 3803.5 26.9
# 284 1214 12.94 3688.0 146.7 3348.4 3815.9 26.3
# 285 1215 12.95 3672.7 144.2 3341.3 3795.2 25.7
# 286 1216 12.96 3655.5 142.5 3333.3 3765.2 25.1
# 287 1217 12.97 3660.1 144.0 3337.0 3774.2 24.4
# 288 1218 12.98 3657.6 138.8 3338.9 3775.1 23.8
# 289 1219 12.99 3651.2 133.5 3339.2 3768.5 23.1
# 290 1220 13.00 3646.5 129.6 3337.7 3765.1 22.4
# 291 1221 13.01 3650.8 124.6 3341.5 3772.0 21.7
# 292 1222 13.02 3653.6 117.7 3343.9 3782.7 21.0
# 293 1223 13.03 3643.4 107.3 3343.5 3780.1 20.4
# 294 1224 13.04 3628.5 96.7 3340.7 3771.4 19.8
# 295 1225 13.05 3633.6 86.1 3343.6 3786.4 19.2
# 296 1226 13.06 3644.1 81.9 3344.5 3801.8 18.8
# 297 1227 13.07 3642.5 76.3 3342.9 3809.2 18.7
# 298 1228 13.08 3644.5 69.2 3344.4 3819.0 18.5
# 299 1229 13.09 3659.6 66.0 3343.8 3834.4 18.3
# 300 1230 13.10 3680.9 58.4 3346.7 3855.5 18.5
# 301 1231 13.11 3693.3 53.7 3346.9 3860.1 18.5
# 302 1232 13.12 3696.0 53.2 3340.7 3852.7 18.4
# 303 1233 13.13 3704.2 54.3 3337.4 3846.0 18.1
# 304 1234 13.14 3738.5 54.9 3345.4 3865.4 18.0
# 305 1235 13.15 3757.1 59.6 3344.2 3863.1 18.1
# 306 1236 13.16 3764.4 71.9 3330.8 3833.2 18.6
# 307 1237 13.17 3786.6 81.1 3330.1 3828.5 19.1
# 308 1238 13.18 3817.2 89.6 3335.8 3836.4 19.7
# 309 1239 13.19 3828.7 94.3 3336.7 3828.7 20.4
# 310 1240 13.20 3830.5 102.9 3328.2 3809.4 21.1
# 311 1241 13.21 3845.6 114.8 3325.7 3796.2 21.8
# 312 1242 13.22 3860.5 125.6 3324.8 3790.9 22.5
# 313 1243 13.23 3857.2 133.8 3318.1 3770.9 23.3
# 314 1244 13.24 3852.1 140.0 3312.7 3752.9 24.0
# 315 1245 13.25 3858.5 146.5 3314.5 3750.0 24.7
# 316 1246 13.26 3861.5 152.2 3314.6 3747.0 25.4
# 317 1247 13.27 3851.2 159.5 3305.1 3728.5 26.1
# 318 1248 13.28 3844.7 164.3 3299.8 3710.3 26.7
# 319 1249 13.29 3842.3 163.0 3301.3 3707.4 27.4
# 320 1250 13.30 3835.1 160.5 3300.2 3705.5 27.9
# 321 1251 13.31 3837.0 166.4 3299.8 3701.0 28.4
# 322 1252 13.32 3833.0 169.1 3298.2 3695.2 28.9
# 323 1253 13.33 3824.9 162.4 3297.9 3693.3 29.4
# 324 1254 13.34 3802.2 156.3 3286.6 3665.9 29.7
# 325 1255 13.35 3786.3 156.7 3275.6 3642.2 29.9
# 326 1256 13.36 3784.6 154.9 3275.5 3641.1 30.0
# 327 1257 13.37 3783.4 148.0 3280.0 3648.5 30.1
# 328 1258 13.38 3780.3 143.3 3280.4 3649.7 30.2
# 329 1259 13.39 3778.1 138.3 3281.0 3639.6 30.4
# 330 1260 13.40 3780.4 127.8 3287.4 3665.7 30.7
# 331 1261 13.41 3775.7 121.1 3287.0 3655.9 31.0
# 332 1262 13.42 3765.5 112.7 3281.1 3640.2 31.1
# 333 1263 13.43 3764.7 104.1 3283.7 3644.8 31.2
# 334 1264 13.44 3775.1 92.9 3292.9 3661.7 31.1
# 335 1265 13.45 3771.2 85.5 3293.8 3663.8 31.1
# 336 1266 13.46 3774.4 79.7 3298.5 3674.7 30.9
# 337 1267 13.47 3794.0 70.2 3308.7 3695.8 30.7
# 338 1268 13.48 3813.0 61.0 3319.0 3722.4 30.4
# 339 1269 13.49 3830.9 56.2 3329.2 3739.1 30.1
# 340 1270 13.50 3849.9 47.9 3336.5 3761.8 29.7
# 341 1271 13.51 3866.2 39.8 3344.5 3778.0 29.3
# 342 1272 13.52 3879.1 35.7 3349.9 3790.1 28.8
# 343 1273 13.53 3899.5 29.3 3358.9 3812.5 28.3
# 344 1274 13.54 3939.3 26.6 3376.7 3862.7 27.7
# 345 1275 13.55 3969.9 25.9 3385.9 3892.5 27.1
# 346 1276 13.56 3995.9 27.2 3394.0 3919.1 26.4
# 347 1277 13.57 4016.6 29.5 3398.8 3938.9 25.7
# 348 1278 13.58 4038.6 33.5 3403.5 3960.7 25.0
# 349 1279 13.59 4073.3 40.1 3404.6 3967.2 24.2
# 350 1280 13.60 4099.5 48.2 3407.1 3987.4 23.4
# 351 1281 13.61 4120.8 56.7 3407.0 3995.5 22.6
# 352 1282 13.62 4168.5 71.1 3403.8 3993.6 21.8
# 353 1283 13.63 4209.5 90.8 3402.4 3986.9 21.2
# 354 1284 13.64 4227.4 108.7 3403.9 3980.0 20.4
# 355 1285 13.65 4235.2 122.5 3404.6 3960.2 19.8
# 356 1286 13.66 4234.5 130.3 3406.8 3942.6 19.4
# 357 1287 13.67 4238.8 142.2 3408.1 3924.9 19.3
# 358 1288 13.68 4244.9 150.4 3412.0 3908.5 19.0
# 359 1289 13.69 4237.7 148.8 3415.3 3903.1 18.9
# 360 1290 13.70 4228.7 144.2 3415.3 3885.9 19.0
# 361 1291 13.71 4237.8 143.7 3414.0 3880.1 18.9
# 362 1292 13.72 4240.2 131.4 3416.0 3882.9 18.8
# 363 1293 13.73 4242.2 108.2 3424.1 3897.0 18.4
# 364 1294 13.74 4235.5 97.0 3424.3 3900.1 18.1
# 365 1295 13.75 4231.6 95.8 3420.7 3896.9 18.0
# 366 1296 13.76 4244.2 107.7 3416.2 3900.9 18.2
# 367 1297 13.77 4253.3 124.8 3406.4 3892.5 18.5
# 368 1298 13.78 4252.2 142.0 3391.6 3867.3 18.9
# 369 1299 13.79 4233.7 157.8 3370.1 3826.6 19.6
# 370 1300 13.80 4204.4 176.3 3342.7 3780.3 20.3
# 371 1301 13.81 4179.6 180.2 3324.1 3739.2 21.1
# 372 1302 13.82 4169.2 158.7 3326.2 3739.0 21.8
# 373 1303 13.83 4163.0 130.9 3334.6 3752.4 22.5
# 374 1304 13.84 4157.5 109.6 3341.9 3760.6 23.2
# 375 1305 13.85 4171.9 83.2 3353.0 3779.1 23.9
# 376 1306 13.86 4203.2 63.0 3368.4 3809.6 24.5
# 377 1307 13.87 4230.3 57.0 3397.4 3859.6 25.0
# 378 1308 13.88 4271.9 70.0 3437.3 3936.6 25.5
# 379 1309 13.89 4287.5 97.6 3485.9 4028.5 26.0
# 380 1310 13.90 4301.8 124.7 3523.7 4121.7 26.4
# 381 1311 13.91 4319.0 147.0 3554.0 4206.9 26.7
# 382 1312 13.92 4364.2 154.1 3579.7 4290.5 27.0
# 383 1313 13.93 4420.5 160.8 3606.5 4372.9 27.2
# 384 1314 13.94 4459.5 165.4 3618.4 4422.9 27.4
# 385 1315 13.95 4498.3 168.9 3627.5 4467.7 27.6
# 386 1316 13.96 4548.8 168.5 3646.9 4518.4 27.7
# 387 1317 13.97 4590.6 166.1 3660.6 4558.0 27.8
# 388 1318 13.98 4620.4 168.7 3670.5 4591.2 28.0
# 389 1319 13.99 4653.2 166.2 3670.1 4600.4 28.0
# 390 1320 14.00 4691.9 160.5 3676.9 4622.9 28.1
# 391 1321 14.01 4720.8 154.7 3683.5 4639.3 28.2
# 392 1322 14.02 4743.5 148.9 3685.0 4643.3 28.2
# 393 1323 14.03 4754.1 145.0 3681.2 4641.8 28.2
# 394 1324 14.04 4759.7 137.7 3677.1 4629.8 28.1
# 395 1325 14.05 4770.6 130.7 3674.4 4625.1 28.1
# 396 1326 14.06 4789.2 125.5 3671.4 4620.2 28.0
# 397 1327 14.07 4812.3 121.7 3671.5 4621.8 27.9
# 398 1328 14.08 4807.1 118.1 3663.6 4598.8 27.8
# 399 1329 14.09 4799.8 114.8 3653.4 4574.3 27.6
# 400 1330 14.10 4803.1 111.9 3645.9 4569.1 27.4
