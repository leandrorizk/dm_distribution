# %%
#I put this code in my jupyter directory. 
#You probably need to change to dir variable below to point to /data/vxtest/519
#You will also need to change the toutfile to the same location
#The cluster number is ncluster and the set of times
#DTmax is the time interval over which particles left recently which will be followed
#The plot starts at ifile_start
 
import numpy as np
import astropy as ast
import scipy as sc
import matplotlib.pyplot as plt
 

dir = '/data/vxtest/519'
DTmax = 0.4
ncluster = 268
ifile_start = 930
 
plt.rcParams["figure.figsize"] = (16,10)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Time [Gyr]',size='x-large')
ax1.set_ylabel('L - <L> [kpc km/sec]',size='x-large')
 
nskip=1
nplot = int((1330-ifile_start)/nskip + 1)
print("nplot ",nplot)
ifile = ifile_start
toutfile =   dir +'/TOUT' + f'{ifile:04}'
thead = np.fromfile(toutfile,dtype='double',count=1)
Tend = thead[0]
print(ifile,Tend)
nnn = np.fromfile(toutfile,dtype='int32',count=3,offset=8)
nstart = nnn[0]
ntc = nnn[1]
nts = nnn[2]
Toffset = 14.1 - Tend
print(Tend,nstart,ntc,nts,Toffset)
noff = 8 + 3*4
Nco = np.zeros(ntc,dtype='int32')
outid = []
ctout = []
for i in range(ntc):
    Nco[i] = np.fromfile(toutfile,dtype='int32',count=1,offset=noff)
    noff += 4
    readoutN = np.fromfile(toutfile,dtype='int32',count=Nco[i],offset=noff)
    outid.append(readoutN)
    noff += 4*Nco[i]
    readoutT= np.fromfile(toutfile,dtype='double',count=Nco[i],offset=noff)
    ctout.append(readoutT)
    noff += 8*Nco[i]

cplot = ctout[ncluster] < DTmax
print("Cluster",ncluster,Tend,DTmax,np.sum(cplot))
ptime = []
Ltime = []
for i in range(nplot):
    ifile = ifile_start + nskip*i
    filename =   dir+'/snapshot_' + f'{ifile:04}'
    hd = np.fromfile(filename,dtype='int32',count=7)
    nd = hd[2]
    ns = hd[5]
    nc = hd[3]
    nb = hd[4]
    head = np.fromfile(filename,dtype='double',count=7,offset=4+6*4)
    time=head[6]
 
    start_d = 0
    start_c = nd
    start_s = nd + nc + nb
    start_b = nd + nc
    block = nd + nc + ns + nb
 
    skipx = 256 + 3*4 + start_b*3*8
    skipv = 256 + 5*4 + (block*3 + start_b*3)*8
    rc = np.fromfile(filename,dtype='double',count=3,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3,offset=skipv)
    xh = rc[0]
    yh = rc[1]
    zh = rc[2]
    vxh = vc[0]
    vyh = vc[1]
    vzh = vc[2]
 
    skipx = 256 + 3*4 + start_c*3*8
    skipv = 256 + 5*4 + (block*3 + start_c*3)*8
    skipi = 256 + 7*4 + block*3*2*8 + start_c*4
    rc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipx)
    vc = np.fromfile(filename,dtype='double',count=3*nc,offset=skipv)
    idc = np.fromfile(filename,dtype='uint32',count=nc,offset=skipi)
    jxc = rc[0::3] - xh
    jyc = rc[1::3] - yh
    jzc = rc[2::3] - zh
 
    jvxc = vc[0::3] - vxh
    jvyc = vc[1::3] - vyh
    jvzc = vc[2::3] - vzh
 
    idc -= nd
    ki = np.zeros(nc,dtype='int32')
    for j in range(nc):
        ix = idc[j]
        ki[ix] = j
 
    rh3 = [xh,yh,zh]
    vh3 = [vxh,vyh,vzh]
 
    #centers unsorted
    jrc3 = np.reshape(rc,(nc,3)) - rh3
    jvc3 = np.reshape(vc,(nc,3)) - vh3
 
    rc3 = jrc3[ki]
    vc3 = jvc3[ki]
 
    #stars
    skipx = 256 + 3*4 + start_s*3*8
    skipv = 256 + 5*4 + block*3*8 + start_s*3*8 #skip over r, and dm+c v's
    skipi = 256 + 7*4 + block*3*2*8 + start_s*4 #skip over r and v and dm+c id
    skipc = 256 + 9*4 + block*(2*3*8+4) + start_s*4 #skip over r, v and id and dm+c ic
 
    rs= np.fromfile(filename,dtype='double',count=3*ns,offset=skipx)
    vs = np.fromfile(filename,dtype='double',count=3*ns,offset=skipv)
    ids = np.fromfile(filename,dtype='uint32',count=ns,offset=skipi)
    jics = np.fromfile(filename,dtype='uint32',count=ns,offset=skipc)
 
    jrs3 = np.reshape(rs,(ns,3)) - rh3
    jvs3 = np.reshape(vs,(ns,3)) - vh3
 
    ids -= nd + nc + nb
    ki = np.zeros(ns,dtype='int32')
    for j in range(ns):
        ix = ids[j]
        ki[ix] = j
 
    rs3 = jrs3[ki]
    vs3 = jvs3[ki]
    ics = jics[ki]
 
    dsm = np.linalg.norm(rs3,axis=1)
    vsm  =np.linalg.norm(vs3,axis=1)
 
    Ls3 = np.cross(rs3,vs3)
    Lsm = np.linalg.norm(Ls3,axis=1)
    vts = Lsm/dsm
    vrs = (rs3*vs3).sum(axis=1)/dsm
 
    dcm = np.linalg.norm(rc3,axis=1)
    vcm  =np.linalg.norm(vc3,axis=1)
 
    Lc3 = np.cross(rc3,vc3)
    Lcm = np.linalg.norm(Lc3,axis=1)
    vtc = Lcm/dcm
    vrc =  (rc3*vc3).sum(axis=1)/dcm
 
    lon = np.arctan2(rs3[:,1],rs3[:,0])
    lat = np.arcsin(rs3[:,2]/dsm)
    Lsz = np.abs(Ls3[:,2])
 
    lonc = np.arctan2(rc3[:,1],rc3[:,0])
    latc = np.arcsin(rc3[:,2]/dcm)
    Lcz = np.abs(Lc3[:,2])
    tempYc3 = -np.cross(rc3,np.cross(rc3,vc3))
    normYc3 = np.sqrt((tempYc3 ** 2).sum(-1))[..., np.newaxis]
    Yc3 = tempYc3 / normYc3
 
    rotx = np.sum(rc3[ics] * rs3,axis=1)/dcm[ics]
    roty = np.sum(Yc3[ics] * rs3,axis=1)
    rotz = np.sum(Lc3[ics] * rs3,axis=1)/Lcm[ics]
    rotlen = np.sqrt(rotx**2 + roty**2 + rotz**2)
    rotlon = np.arctan2(roty,rotx)
    rotlat = np.arcsin(rotz/rotlen)
    if i == 0:
        inLs30 = Ls3[outid[ncluster]]
   
    rotvx = np.sum(rc3[ics] * vs3,axis=1)/dcm[ics]
    rotvy = np.sum(Yc3[ics] * vs3,axis=1)
    rotvz = np.sum(Lc3[ics] * vs3,axis=1)/Lcm[ics]
 
    rotcx = np.sum(rc3 * rc3,axis=1)/dcm
    rotcy = np.sum(Yc3 * rc3,axis=1)
    rotcz = np.sum(Lc3 * rc3,axis=1)/Lcm
 
    rotclen = np.sqrt(rotcx**2 + rotcy**2 + rotcz**2)
    rotclon = np.arctan2(rotcy,rotcx)
    rotclat = np.arcsin(rotcz/rotclen)
 
    inLs3 = Ls3[outid[ncluster]]
    Lsav = np.mean(np.linalg.norm(inLs3,axis=1))
    dLs = inLs3[cplot] - inLs30[cplot] #- Lc3[ncluster]
    dLm = np.linalg.norm(dLs,axis=1)
    dLav = np.median(dLm)
    dLst = np.var(dLm)
    dLm -= dLav
    atime = np.full_like(dLm,time)
    ptime.append(atime)
    Ltime.append(dLm)
    ax1.scatter(time,Lsav/40,color='black',s=2) #L scaling
    indsm = dsm[outid[ncluster]]
    dmedian = np.median(indsm[cplot])
    ax1.scatter(time,(dmedian-200),color='red',s=2) #L scaling
    print(i,ifile,f'{time:.2f} {dLav:.1f} {np.sqrt(dLst):.1f} {Lsav:.1f} {Lcm[ncluster]:.1f} {dmedian:.1f}')
    #plotoff += plotinc
# Out:
# nplot  401
# 930 10.099999999153177
# 10.099999999153177 930 271 4718000 4.000000000846823
# Cluster 268 10.099999999153177 0.4 119
# 0 930 10.10 0.0 0.0 7408.9 3173.2 19.8
# 1 931 10.11 26.4 0.5 7392.5 3169.5 21.8
# 2 932 10.12 44.1 2.0 7371.0 3145.9 23.7
# 3 933 10.13 71.5 2.3 7346.5 3128.0 25.7
# 4 934 10.14 120.5 2.3 7342.7 3106.8 27.6
# 5 935 10.15 153.8 3.2 7288.0 3097.1 29.5
# 6 936 10.16 212.2 4.1 7283.2 3079.3 31.3
# 7 937 10.17 281.2 5.5 7267.9 3074.5 33.1
# 8 938 10.18 348.0 6.7 7207.3 3061.1 34.9
# 9 939 10.19 414.1 7.4 7179.6 3065.4 36.6
# 10 940 10.20 482.3 7.7 7114.7 3072.8 38.3
# 11 941 10.21 572.2 8.0 6990.1 3072.2 39.9
# 12 942 10.22 694.2 8.2 6848.8 3160.1 41.6
# 13 943 10.23 749.2 7.9 6583.9 3350.4 43.2
# 14 944 10.24 804.2 9.9 6220.2 3715.1 44.9
# 15 945 10.25 880.7 12.8 6013.8 3954.6 46.5
# 16 946 10.26 908.9 13.2 6009.1 4051.1 48.1
# 17 947 10.27 922.5 12.8 6122.5 4083.7 49.5
# 18 948 10.28 895.1 13.4 6241.8 4056.0 50.9
# 19 949 10.29 842.4 11.4 6338.8 3990.0 52.2
# 20 950 10.30 818.6 12.4 6418.2 3961.1 53.4
# 21 951 10.31 780.7 12.3 6504.3 3907.8 54.5
# 22 952 10.32 739.5 12.3 6562.1 3850.9 55.5
# 23 953 10.33 705.4 12.6 6608.5 3795.9 56.5
# 24 954 10.34 678.4 13.0 6660.0 3754.9 57.4
# 25 955 10.35 672.8 12.5 6710.4 3732.2 58.3
# 26 956 10.36 651.5 11.6 6721.5 3695.5 59.1
# 27 957 10.37 622.8 10.8 6757.3 3628.9 59.9
# 28 958 10.38 616.3 10.3 6788.5 3583.6 60.6
# 29 959 10.39 610.8 10.1 6789.2 3535.4 61.2
# 30 960 10.40 608.1 10.2 6795.1 3521.2 61.9
# 31 961 10.41 621.0 10.6 6806.7 3495.7 62.4
# 32 962 10.42 650.4 11.3 6818.2 3472.2 63.0
# 33 963 10.43 670.7 11.7 6816.8 3445.6 63.5
# 34 964 10.44 667.7 11.5 6826.8 3464.6 63.9
# 35 965 10.45 655.5 11.4 6826.5 3458.9 64.3
# 36 966 10.46 664.5 12.1 6826.9 3424.4 64.6
# 37 967 10.47 668.6 13.0 6819.1 3407.2 64.9
# 38 968 10.48 660.4 14.0 6801.3 3418.8 65.2
# 39 969 10.49 683.0 15.6 6809.0 3401.1 65.4
# 40 970 10.50 753.7 17.2 6804.7 3410.5 65.6
# 41 971 10.51 773.1 18.1 6800.3 3408.3 65.8
# 42 972 10.52 756.6 18.6 6793.8 3393.2 65.9
# 43 973 10.53 748.0 18.8 6780.7 3406.7 65.9
# 44 974 10.54 773.8 18.8 6761.7 3400.1 66.0
# 45 975 10.55 779.1 19.1 6751.4 3391.5 66.0
# 46 976 10.56 769.7 19.6 6741.4 3400.2 65.9
# 47 977 10.57 770.3 19.7 6741.6 3410.1 65.8
# 48 978 10.58 764.5 19.8 6723.7 3427.4 65.7
# 49 979 10.59 756.7 19.8 6699.6 3431.5 65.6
# 50 980 10.60 783.7 19.9 6679.1 3426.1 65.4
# 51 981 10.61 760.4 19.8 6664.2 3404.9 65.1
# 52 982 10.62 689.3 19.9 6645.6 3375.0 64.9
# 53 983 10.63 717.2 20.0 6629.4 3434.3 64.6
# 54 984 10.64 744.5 20.1 6604.6 3458.0 64.3
# 55 985 10.65 734.0 20.1 6587.7 3452.6 63.9
# 56 986 10.66 737.2 20.2 6573.0 3478.7 63.5
# 57 987 10.67 721.1 20.4 6555.2 3500.6 63.1
# 58 988 10.68 712.6 20.2 6538.9 3485.6 62.7
# 59 989 10.69 726.7 20.2 6519.0 3502.7 62.2
# 60 990 10.70 721.0 20.5 6501.1 3536.1 61.6
# 61 991 10.71 726.0 20.6 6485.9 3537.1 61.1
# 62 992 10.72 709.8 20.4 6471.5 3495.6 60.5
# 63 993 10.73 693.0 20.5 6456.8 3491.4 59.9
# 64 994 10.74 709.1 20.7 6439.6 3533.6 59.2
# 65 995 10.75 705.6 20.9 6428.7 3540.9 58.5
# 66 996 10.76 678.3 21.2 6420.5 3523.6 57.8
# 67 997 10.77 711.4 21.4 6410.6 3536.2 57.0
# 68 998 10.78 720.7 21.6 6399.9 3551.0 56.2
# 69 999 10.79 658.4 22.2 6390.1 3563.2 55.4
# 70 1000 10.80 644.3 22.3 6384.4 3544.3 54.5
# 71 1001 10.81 657.0 22.4 6377.6 3552.2 53.6
# 72 1002 10.82 641.1 23.0 6369.2 3557.9 52.6
# 73 1003 10.83 638.6 22.9 6363.9 3582.7 51.6
# 74 1004 10.84 654.3 22.7 6362.3 3571.6 50.6
# 75 1005 10.85 636.7 23.1 6359.4 3553.1 49.5
# 76 1006 10.86 670.7 23.5 6351.7 3590.9 48.4
# 77 1007 10.87 696.7 23.9 6348.2 3608.6 47.2
# 78 1008 10.88 699.7 24.2 6349.1 3614.4 46.0
# 79 1009 10.89 730.6 24.6 6344.0 3653.3 44.8
# 80 1010 10.90 760.8 24.6 6342.9 3668.2 43.5
# 81 1011 10.91 754.8 25.0 6345.0 3659.6 42.1
# 82 1012 10.92 762.0 25.5 6343.8 3682.7 40.8
# 83 1013 10.93 795.3 26.1 6340.2 3752.2 39.3
# 84 1014 10.94 787.9 26.5 6355.9 3778.7 37.9
# 85 1015 10.95 735.0 27.1 6378.2 3749.0 36.4
# 86 1016 10.96 710.5 27.8 6384.3 3716.7 34.8
# 87 1017 10.97 712.8 28.7 6378.3 3708.8 33.2
# 88 1018 10.98 723.6 29.5 6375.5 3707.9 31.6
# 89 1019 10.99 731.3 30.3 6376.1 3695.8 29.9
# 90 1020 11.00 743.2 30.9 6378.3 3697.8 28.2
# 91 1021 11.01 754.9 31.9 6379.9 3708.8 26.5
# 92 1022 11.02 773.0 32.6 6387.8 3725.6 24.7
# 93 1023 11.03 784.9 34.0 6392.9 3735.1 22.9
# 94 1024 11.04 810.6 34.5 6400.6 3754.1 21.1
# 95 1025 11.05 835.2 35.3 6403.5 3781.0 19.3
# 96 1026 11.06 860.9 36.0 6399.1 3811.1 17.5
# 97 1027 11.07 892.9 35.3 6398.3 3846.3 15.9
# 98 1028 11.08 917.2 34.4 6404.0 3876.7 14.5
# 99 1029 11.09 932.5 33.5 6418.9 3894.8 13.4
# 100 1030 11.10 945.1 31.7 6430.8 3910.7 12.8
# 101 1031 11.11 958.2 30.2 6434.8 3929.1 12.7
# 102 1032 11.12 953.3 35.5 6438.4 3934.5 13.0
# 103 1033 11.13 927.5 40.0 6447.9 3900.7 13.9
# 104 1034 11.14 904.9 39.3 6442.4 3861.8 15.1
# 105 1035 11.15 872.9 36.2 6455.1 3818.0 16.6
# 106 1036 11.16 851.4 33.3 6450.3 3788.7 18.2
# 107 1037 11.17 840.4 30.8 6452.4 3774.0 20.0
# 108 1038 11.18 837.6 28.9 6455.2 3769.6 21.7
# 109 1039 11.19 847.1 27.7 6451.6 3754.5 23.5
# 110 1040 11.20 828.8 27.5 6462.5 3731.9 25.2
# 111 1041 11.21 827.4 27.8 6458.4 3713.2 27.0
# 112 1042 11.22 824.4 28.2 6452.2 3691.6 28.7
# 113 1043 11.23 826.8 28.4 6428.3 3676.9 30.4
# 114 1044 11.24 843.2 29.3 6428.5 3690.4 32.0
# 115 1045 11.25 842.6 30.1 6432.9 3691.8 33.6
# 116 1046 11.26 837.4 30.5 6420.9 3678.3 35.1
# 117 1047 11.27 862.3 31.6 6420.8 3687.7 36.6
# 118 1048 11.28 899.9 32.9 6422.9 3708.8 38.1
# 119 1049 11.29 894.3 33.0 6416.2 3688.1 39.5
# 120 1050 11.30 900.9 33.3 6410.4 3674.3 40.9
# 121 1051 11.31 945.0 34.1 6399.4 3711.1 42.2
# 122 1052 11.32 952.5 34.6 6396.6 3731.8 43.5
# 123 1053 11.33 941.6 34.8 6389.9 3718.1 44.7
# 124 1054 11.34 958.8 35.6 6399.8 3723.0 45.9
# 125 1055 11.35 1009.5 36.5 6393.6 3767.9 47.1
# 126 1056 11.36 1050.4 37.4 6398.0 3794.8 48.2
# 127 1057 11.37 1063.7 37.3 6380.7 3811.0 49.3
# 128 1058 11.38 1080.4 37.5 6378.5 3805.1 50.3
# 129 1059 11.39 1104.0 38.4 6398.7 3826.0 51.3
# 130 1060 11.40 1119.1 39.8 6404.2 3863.4 52.3
# 131 1061 11.41 1150.7 40.5 6382.1 3894.3 53.2
# 132 1062 11.42 1191.4 41.9 6391.9 3904.7 54.1
# 133 1063 11.43 1223.8 43.6 6392.7 3947.6 54.9
# 134 1064 11.44 1234.4 45.4 6405.3 3952.6 55.7
# 135 1065 11.45 1257.7 46.9 6412.5 3950.9 56.5
# 136 1066 11.46 1258.1 47.5 6397.9 3943.0 57.2
# 137 1067 11.47 1304.5 48.3 6385.1 3978.3 57.9
# 138 1068 11.48 1354.5 49.1 6416.6 4002.6 58.6
# 139 1069 11.49 1370.8 49.5 6426.8 3990.1 59.2
# 140 1070 11.50 1373.9 50.1 6431.6 3986.3 59.7
# 141 1071 11.51 1414.6 50.5 6433.8 4014.2 60.3
# 142 1072 11.52 1430.1 51.2 6458.9 4054.7 60.8
# 143 1073 11.53 1462.1 50.8 6461.5 4037.7 61.2
# 144 1074 11.54 1496.4 50.8 6477.6 4046.7 61.6
# 145 1075 11.55 1515.7 51.0 6487.4 4057.7 62.0
# 146 1076 11.56 1516.3 51.4 6505.8 4084.6 62.3
# 147 1077 11.57 1549.3 51.5 6520.2 4117.2 62.6
# 148 1078 11.58 1575.8 50.8 6517.2 4113.0 62.9
# 149 1079 11.59 1572.4 50.4 6532.3 4100.7 63.1
# 150 1080 11.60 1599.0 49.9 6540.3 4104.1 63.3
# 151 1081 11.61 1663.3 49.3 6544.8 4168.0 63.4
# 152 1082 11.62 1690.8 50.5 6581.4 4215.1 63.6
# 153 1083 11.63 1707.7 51.1 6596.2 4257.2 63.6
# 154 1084 11.64 1726.0 51.0 6595.3 4275.7 63.7
# 155 1085 11.65 1777.4 50.6 6580.8 4344.1 63.7
# 156 1086 11.66 1854.5 50.3 6570.4 4465.9 63.7
# 157 1087 11.67 1892.0 50.0 6556.0 4530.7 63.6
# 158 1088 11.68 1897.6 49.5 6526.9 4533.3 63.5
# 159 1089 11.69 1929.7 49.0 6515.8 4566.0 63.4
# 160 1090 11.70 1987.1 48.0 6491.9 4625.0 63.2
# 161 1091 11.71 2001.3 47.5 6491.3 4601.4 63.1
# 162 1092 11.72 2024.2 45.7 6473.4 4605.4 62.9
# 163 1093 11.73 2070.2 44.9 6462.0 4657.0 62.6
# 164 1094 11.74 2085.2 44.7 6453.4 4656.3 62.4
# 165 1095 11.75 2092.4 44.7 6448.1 4637.6 62.1
# 166 1096 11.76 2123.5 47.1 6455.9 4632.5 61.7
# 167 1097 11.77 2171.5 57.1 6456.1 4679.1 61.4
# 168 1098 11.78 2245.9 57.4 6450.9 4746.5 61.0
# 169 1099 11.79 2284.3 46.5 6475.8 4760.9 60.5
# 170 1100 11.80 2307.7 41.1 6475.0 4741.5 60.1
# 171 1101 11.81 2352.1 39.2 6485.4 4775.8 59.6
# 172 1102 11.82 2385.4 38.2 6482.5 4800.5 59.1
# 173 1103 11.83 2422.2 38.4 6493.5 4858.6 58.5
# 174 1104 11.84 2455.8 37.5 6493.2 4888.0 57.9
# 175 1105 11.85 2471.7 37.2 6503.1 4882.8 57.3
# 176 1106 11.86 2483.4 37.2 6493.5 4898.4 56.6
# 177 1107 11.87 2507.2 37.3 6498.5 4931.6 55.9
# 178 1108 11.88 2546.8 36.1 6510.5 4966.5 55.2
# 179 1109 11.89 2564.9 35.7 6523.6 4985.4 54.5
# 180 1110 11.90 2619.0 33.7 6535.5 5034.1 53.7
# 181 1111 11.91 2644.2 32.3 6521.5 5066.2 52.8
# 182 1112 11.92 2651.9 32.6 6516.4 5089.3 52.0
# 183 1113 11.93 2677.5 32.4 6514.3 5123.2 51.1
# 184 1114 11.94 2723.1 31.3 6518.9 5163.7 50.2
# 185 1115 11.95 2734.8 31.2 6524.7 5181.3 49.2
# 186 1116 11.96 2750.3 30.5 6514.0 5199.6 48.2
# 187 1117 11.97 2778.1 30.0 6518.6 5235.3 47.2
# 188 1118 11.98 2805.8 28.1 6520.7 5253.8 46.1
# 189 1119 11.99 2809.5 27.0 6518.8 5262.1 45.1
# 190 1120 12.00 2829.5 25.7 6493.8 5299.1 44.0
# 191 1121 12.01 2849.2 24.5 6492.8 5323.2 42.8
# 192 1122 12.02 2860.2 23.1 6497.4 5329.3 41.7
# 193 1123 12.03 2879.1 22.4 6492.1 5360.2 40.5
# 194 1124 12.04 2879.7 22.0 6469.1 5370.6 39.3
# 195 1125 12.05 2863.3 21.5 6459.1 5354.4 38.1
# 196 1126 12.06 2898.6 21.8 6467.8 5390.3 36.8
# 197 1127 12.07 2919.8 23.1 6464.9 5420.4 35.6
# 198 1128 12.08 2903.2 23.7 6436.1 5407.1 34.3
# 199 1129 12.09 2906.5 26.3 6437.4 5411.3 33.0
# 200 1130 12.10 2924.8 31.4 6434.6 5432.8 31.7
# 201 1131 12.11 2918.6 34.1 6425.7 5432.6 30.5
# 202 1132 12.12 2912.2 38.1 6423.6 5422.8 29.2
# 203 1133 12.13 2920.0 43.2 6427.7 5422.3 28.0
# 204 1134 12.14 2908.0 48.0 6414.0 5406.0 26.8
# 205 1135 12.15 2889.4 52.9 6394.0 5382.7 25.7
# 206 1136 12.16 2876.9 57.3 6389.4 5363.7 24.6
# 207 1137 12.17 2859.4 60.1 6387.9 5340.5 23.6
# 208 1138 12.18 2838.4 61.0 6378.0 5312.0 22.7
# 209 1139 12.19 2822.1 63.6 6378.3 5290.8 21.9
# 210 1140 12.20 2800.8 59.8 6374.0 5261.6 21.3
# 211 1141 12.21 2770.2 53.1 6361.5 5221.3 20.8
# 212 1142 12.22 2753.5 49.1 6356.4 5197.1 20.7
# 213 1143 12.23 2733.2 42.0 6346.6 5171.4 20.6
# 214 1144 12.24 2715.2 34.7 6344.3 5155.3 20.6
# 215 1145 12.25 2713.5 30.0 6349.2 5149.8 20.7
# 216 1146 12.26 2722.3 23.8 6343.2 5147.9 20.9
# 217 1147 12.27 2743.4 21.5 6341.6 5164.7 21.4
# 218 1148 12.28 2747.2 24.1 6334.0 5162.1 22.0
# 219 1149 12.29 2748.2 27.0 6331.8 5164.0 22.8
# 220 1150 12.30 2770.1 30.6 6339.1 5193.6 23.7
# 221 1151 12.31 2793.0 33.6 6345.1 5223.5 24.6
# 222 1152 12.32 2798.6 36.0 6336.0 5224.5 25.6
# 223 1153 12.33 2809.4 37.3 6332.8 5236.3 26.7
# 224 1154 12.34 2837.2 38.3 6336.7 5268.9 27.8
# 225 1155 12.35 2870.4 38.8 6339.1 5297.5 29.0
# 226 1156 12.36 2905.7 39.5 6344.6 5338.9 30.1
# 227 1157 12.37 2929.1 39.4 6348.8 5374.5 31.3
# 228 1158 12.38 2925.6 36.0 6351.3 5373.9 32.5
# 229 1159 12.39 2953.6 34.5 6353.1 5400.0 33.7
# 230 1160 12.40 2986.7 33.0 6361.4 5437.1 34.8
# 231 1161 12.41 2997.7 30.9 6365.7 5453.2 36.0
# 232 1162 12.42 3002.9 28.3 6364.7 5456.2 37.2
# 233 1163 12.43 3027.3 25.8 6369.8 5479.2 38.3
# 234 1164 12.44 3036.2 23.7 6373.2 5490.1 39.4
# 235 1165 12.45 3031.1 21.8 6374.1 5488.5 40.5
# 236 1166 12.46 3059.0 20.6 6380.4 5521.0 41.6
# 237 1167 12.47 3112.0 20.3 6387.2 5587.5 42.6
# 238 1168 12.48 3103.0 19.2 6388.7 5575.9 43.6
# 239 1169 12.49 3104.8 19.0 6389.0 5568.4 44.6
# 240 1170 12.50 3144.7 20.1 6392.3 5604.2 45.6
# 241 1171 12.51 3170.6 21.2 6395.7 5637.3 46.6
# 242 1172 12.52 3172.3 22.8 6397.1 5641.3 47.5
# 243 1173 12.53 3156.6 23.0 6396.3 5628.1 48.4
# 244 1174 12.54 3145.4 25.9 6393.7 5611.4 49.3
# 245 1175 12.55 3167.4 28.9 6393.5 5629.5 50.1
# 246 1176 12.56 3175.7 30.5 6392.9 5638.5 50.9
# 247 1177 12.57 3169.3 31.6 6392.1 5638.0 51.7
# 248 1178 12.58 3153.4 33.8 6390.5 5627.0 52.5
# 249 1179 12.59 3151.2 36.2 6388.3 5614.7 53.2
# 250 1180 12.60 3107.8 38.4 6381.1 5561.0 53.9
# 251 1181 12.61 3093.2 39.0 6379.0 5549.8 54.6
# 252 1182 12.62 3088.9 43.0 6375.3 5537.8 55.2
# 253 1183 12.63 3085.4 43.7 6372.8 5533.2 55.8
# 254 1184 12.64 3061.0 43.9 6370.4 5508.6 56.4
# 255 1185 12.65 3044.9 43.8 6372.7 5487.1 57.0
# 256 1186 12.66 3038.9 44.5 6372.7 5474.8 57.5
# 257 1187 12.67 2987.8 45.6 6369.6 5420.5 57.9
# 258 1188 12.68 2967.9 45.3 6372.0 5399.5 58.4
# 259 1189 12.69 2964.7 46.1 6369.2 5396.2 58.8
# 260 1190 12.70 2954.9 46.4 6362.6 5384.1 59.2
# 261 1191 12.71 2918.9 45.2 6362.4 5338.6 59.6
# 262 1192 12.72 2873.5 45.8 6364.0 5288.8 59.9
# 263 1193 12.73 2854.0 46.5 6361.9 5268.9 60.2
# 264 1194 12.74 2847.4 45.5 6366.8 5255.7 60.5
# 265 1195 12.75 2801.4 44.1 6365.9 5203.9 60.7
# 266 1196 12.76 2794.9 43.3 6366.1 5197.9 60.8
# 267 1197 12.77 2786.0 46.0 6364.3 5193.5 61.0
# 268 1198 12.78 2771.0 45.3 6368.2 5169.3 61.1
# 269 1199 12.79 2717.5 41.6 6363.0 5085.7 61.2
# 270 1200 12.80 2695.1 40.6 6361.8 5055.6 61.3
# 271 1201 12.81 2671.8 41.5 6361.8 5036.4 61.3
# 272 1202 12.82 2650.8 39.8 6359.7 4997.5 61.4
# 273 1203 12.83 2640.5 37.8 6355.1 4969.5 61.4
# 274 1204 12.84 2608.1 39.2 6358.9 4944.6 61.3
# 275 1205 12.85 2594.0 38.7 6365.1 4927.0 61.2
# 276 1206 12.86 2564.4 36.7 6357.5 4873.4 61.1
# 277 1207 12.87 2542.4 35.8 6351.9 4838.7 60.9
# 278 1208 12.88 2532.1 36.0 6359.5 4828.2 60.8
# 279 1209 12.89 2524.1 33.5 6358.1 4788.4 60.5
# 280 1210 12.90 2517.4 31.3 6350.1 4760.3 60.3
# 281 1211 12.91 2528.0 31.8 6345.0 4760.3 60.0
# 282 1212 12.92 2484.3 32.5 6335.5 4723.2 59.7
# 283 1213 12.93 2471.3 31.3 6345.2 4697.7 59.4
# 284 1214 12.94 2480.2 30.6 6368.3 4705.3 59.0
# 285 1215 12.95 2480.5 31.3 6360.8 4700.1 58.6
# 286 1216 12.96 2468.6 31.7 6345.5 4672.8 58.1
# 287 1217 12.97 2441.9 29.9 6350.6 4618.8 57.6
# 288 1218 12.98 2432.3 29.8 6358.1 4603.9 57.1
# 289 1219 12.99 2407.3 29.5 6355.0 4563.0 56.5
# 290 1220 13.00 2416.2 29.1 6355.2 4542.8 56.0
# 291 1221 13.01 2404.6 27.8 6365.4 4532.4 55.3
# 292 1222 13.02 2409.0 27.5 6376.4 4516.8 54.6
# 293 1223 13.03 2389.0 27.5 6363.4 4476.8 53.9
# 294 1224 13.04 2375.9 27.4 6340.7 4439.1 53.1
# 295 1225 13.05 2368.2 26.5 6346.8 4423.8 52.4
# 296 1226 13.06 2373.8 25.1 6361.4 4400.3 51.5
# 297 1227 13.07 2365.6 23.9 6352.2 4357.5 50.7
# 298 1228 13.08 2341.0 22.5 6339.1 4300.2 49.7
# 299 1229 13.09 2346.0 21.9 6354.3 4290.5 48.8
# 300 1230 13.10 2335.7 21.8 6359.5 4273.0 47.8
# 301 1231 13.11 2328.1 21.1 6355.8 4243.2 46.8
# 302 1232 13.12 2345.1 20.7 6348.8 4213.7 45.7
# 303 1233 13.13 2343.8 20.2 6344.8 4176.3 44.6
# 304 1234 13.14 2303.2 19.7 6346.5 4147.0 43.4
# 305 1235 13.15 2302.2 19.6 6348.8 4124.5 42.2
# 306 1236 13.16 2336.1 20.0 6369.7 4123.8 41.0
# 307 1237 13.17 2326.3 20.2 6374.0 4110.2 39.7
# 308 1238 13.18 2295.9 20.6 6369.8 4078.1 38.3
# 309 1239 13.19 2292.3 21.0 6355.3 4035.6 37.0
# 310 1240 13.20 2319.5 21.0 6358.7 4028.9 35.5
# 311 1241 13.21 2316.2 21.7 6365.0 4018.1 34.1
# 312 1242 13.22 2304.9 22.9 6368.0 3995.9 32.6
# 313 1243 13.23 2312.4 24.0 6374.2 3981.4 31.0
# 314 1244 13.24 2324.2 24.7 6377.2 3966.9 29.4
# 315 1245 13.25 2319.5 26.4 6372.2 3952.2 27.8
# 316 1246 13.26 2319.5 28.8 6369.8 3943.4 26.1
# 317 1247 13.27 2323.2 33.2 6386.7 3941.7 24.5
# 318 1248 13.28 2331.9 35.0 6395.0 3941.3 22.8
# 319 1249 13.29 2341.4 35.0 6386.5 3930.2 21.1
# 320 1250 13.30 2353.6 34.7 6382.9 3927.8 19.4
# 321 1251 13.31 2350.8 38.0 6387.4 3931.7 17.8
# 322 1252 13.32 2357.7 37.6 6392.5 3941.2 16.3
# 323 1253 13.33 2373.2 35.5 6389.4 3951.5 15.0
# 324 1254 13.34 2391.5 32.9 6407.9 3979.7 14.4
# 325 1255 13.35 2403.7 34.8 6428.4 4008.9 14.2
# 326 1256 13.36 2411.8 35.8 6428.6 4024.7 14.2
# 327 1257 13.37 2420.4 30.7 6421.4 4032.7 13.7
# 328 1258 13.38 2427.9 28.8 6421.8 4041.0 14.1
# 329 1259 13.39 2435.9 26.9 6422.1 4045.4 15.1
# 330 1260 13.40 2434.2 23.1 6414.1 4038.5 16.5
# 331 1261 13.41 2435.2 22.9 6417.5 4021.4 18.1
# 332 1262 13.42 2441.9 24.2 6430.6 4001.0 19.8
# 333 1263 13.43 2441.3 26.2 6430.5 3969.6 21.5
# 334 1264 13.44 2434.1 28.6 6418.7 3936.4 23.3
# 335 1265 13.45 2428.2 28.7 6421.5 3888.9 25.1
# 336 1266 13.46 2422.2 27.2 6415.9 3842.9 26.8
# 337 1267 13.47 2415.2 26.5 6401.4 3815.9 28.5
# 338 1268 13.48 2405.0 26.0 6388.0 3780.8 30.2
# 339 1269 13.49 2409.0 25.0 6370.4 3748.7 31.8
# 340 1270 13.50 2409.7 25.2 6362.9 3721.2 33.4
# 341 1271 13.51 2400.0 25.7 6357.0 3684.1 34.9
# 342 1272 13.52 2419.1 26.0 6349.5 3664.5 36.3
# 343 1273 13.53 2406.2 26.2 6344.2 3633.2 37.7
# 344 1274 13.54 2377.9 26.7 6315.7 3613.3 39.0
# 345 1275 13.55 2375.7 26.9 6302.8 3609.6 40.3
# 346 1276 13.56 2367.9 27.0 6289.5 3595.1 41.5
# 347 1277 13.57 2357.8 26.9 6285.2 3574.3 42.6
# 348 1278 13.58 2334.3 26.8 6284.8 3535.0 43.7
# 349 1279 13.59 2326.5 26.6 6287.7 3529.2 44.8
# 350 1280 13.60 2295.1 26.4 6285.9 3501.9 45.7
# 351 1281 13.61 2279.1 25.8 6296.0 3471.7 46.7
# 352 1282 13.62 2291.7 25.6 6306.1 3465.0 47.6
# 353 1283 13.63 2298.7 26.8 6319.6 3452.8 48.4
# 354 1284 13.64 2290.6 29.9 6338.9 3424.8 49.2
# 355 1285 13.65 2305.7 34.9 6362.4 3405.2 49.9
# 356 1286 13.66 2317.9 40.8 6386.5 3360.5 50.7
# 357 1287 13.67 2320.5 46.6 6405.9 3347.9 51.3
# 358 1288 13.68 2312.3 51.5 6431.3 3329.3 52.0
# 359 1289 13.69 2311.0 55.7 6453.3 3296.6 52.6
# 360 1290 13.70 2311.2 58.9 6469.3 3287.7 53.1
# 361 1291 13.71 2252.1 60.8 6481.7 3260.0 53.7
# 362 1292 13.72 2220.7 63.1 6501.3 3225.2 54.2
# 363 1293 13.73 2195.5 67.4 6527.8 3141.2 54.6
# 364 1294 13.74 2182.1 69.5 6542.0 3112.1 55.1
# 365 1295 13.75 2122.5 70.9 6549.6 3075.9 55.4
# 366 1296 13.76 1989.5 72.4 6561.4 3019.0 55.8
# 367 1297 13.77 1827.8 72.9 6571.8 2975.7 56.0
# 368 1298 13.78 1679.9 70.9 6579.7 2970.4 56.2
# 369 1299 13.79 1573.9 64.1 6580.9 3019.0 56.3
# 370 1300 13.80 1472.2 54.7 6580.1 3120.2 56.4
# 371 1301 13.81 1426.5 50.7 6579.2 3197.1 56.4
# 372 1302 13.82 1487.1 51.1 6571.8 3237.9 56.4
# 373 1303 13.83 1579.8 51.9 6562.8 3285.1 56.3
# 374 1304 13.84 1638.0 52.4 6558.1 3334.7 56.3
# 375 1305 13.85 1724.9 53.3 6548.5 3397.8 56.2
# 376 1306 13.86 1790.6 54.3 6541.7 3438.4 56.1
# 377 1307 13.87 1869.5 55.3 6541.4 3479.9 55.9
# 378 1308 13.88 1946.6 55.6 6545.1 3492.3 55.6
# 379 1309 13.89 2043.2 55.9 6553.3 3494.6 55.3
# 380 1310 13.90 2134.2 56.4 6560.0 3537.5 54.9
# 381 1311 13.91 2251.8 57.7 6567.3 3638.2 54.5
# 382 1312 13.92 2289.3 57.8 6583.9 3632.7 54.1
# 383 1313 13.93 2349.1 58.2 6604.3 3633.9 53.6
# 384 1314 13.94 2401.3 58.6 6617.1 3666.0 53.0
# 385 1315 13.95 2454.6 59.0 6630.5 3708.4 52.4
# 386 1316 13.96 2506.7 59.3 6655.7 3705.5 51.8
# 387 1317 13.97 2547.2 59.5 6677.9 3713.6 51.0
# 388 1318 13.98 2615.5 59.9 6694.0 3777.7 50.3
# 389 1319 13.99 2645.5 60.1 6705.2 3800.4 49.5
# 390 1320 14.00 2675.5 60.3 6725.2 3804.2 48.7
# 391 1321 14.01 2705.9 60.6 6745.2 3807.6 47.8
# 392 1322 14.02 2728.6 60.9 6760.4 3819.4 46.9
# 393 1323 14.03 2754.5 61.0 6769.1 3854.1 45.9
# 394 1324 14.04 2761.4 61.2 6781.1 3854.1 44.9
# 395 1325 14.05 2772.2 61.2 6795.9 3855.9 43.8
# 396 1326 14.06 2791.1 61.2 6811.0 3862.7 42.8
# 397 1327 14.07 2817.9 61.4 6830.1 3865.1 41.6
# 398 1328 14.08 2829.5 61.3 6834.4 3898.6 40.4
# 399 1329 14.09 2835.2 61.6 6834.8 3936.9 39.2
# 400 1330 14.10 2850.3 61.9 6843.1 3961.0 37.9

# %%
encounter_time_1 = 11.12
encounter_time_2 = 11.26
encounter_time_3 = 11.78
encounter_time_4 = 12.53
encounter_time_5 = 13.35
encounter_time_6 = 13.50
encounter_time_7 = 13.68

# %%
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams.update({'font.size': 14})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gy]', size=18)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=18)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

plt.axvspan(encounter_time_3 - 0.04, encounter_time_3 + 0.04,
            color='silver', alpha=0.5)
            #label='Close encounter with DM subhalo')

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

#plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (15, 8)
plt.rcParams.update({'font.size': 20})
 
fig, (ax1) = plt.subplots()
#ax1.set_xlim(-90,90)
#ax1.get_yaxis().set_visible(False)
#ax1.set_xlim(-180,180)
#ax1.grid(True)
#ygrid = np.arange(200)*30
#ax1.set_yticks(ygrid)
ax1.set_xlabel('Age  [Gy]', size=20)
ax1.set_ylabel(r'$\Delta \, L$  [kpc$\cdot$km/s]', size=20)

#ax1.set_xlim(Tend-DTmax/2,14.2)
ax1.set_xlim(10.1, 13.9)
ax1.set_ylim(-200,200)

plt.axvspan(encounter_time_3 - 0.04, encounter_time_3 + 0.04,
            color='silver', alpha=0.5)
            #label='Close encounter with DM subhalo')

for ip in range(len(dLm)):
    plott = np.zeros(nplot)
    plotL = np.zeros(nplot)
    for it in range(nplot):
        plott[it] =ptime[it][ip]
        plotL[it] =Ltime[it][ip]
    ax1.plot(plott,plotL,linewidth=1)#,color='black')

#ax1.annotate('Nc '+ f'{ncluster:04}' + " DT "+f'{DTmax:3.1f}' + ' Lscale=40',xy=(Tend,180))#,size='large')
# #plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.jpeg',dpi=300)
# plt.savefig("DLT" + f'{ifile_start:04}'+"_" f'{ncluster:04}'+ '.pdf',dpi=300)

#plt.axvline(x=encounter_time_1, ls='--', color='k')
#plt.axvline(x=encounter_time_2, ls='--', color='k')
#plt.axvline(x=encounter_time_3, ls='--', color='k', label='Close encounter with DM subhalo')
# plt.axvline(x=encounter_time_4, ls='--', color='k')
# plt.axvline(x=encounter_time_5, ls='--', color='k')
# plt.axvline(x=encounter_time_6, ls='--', color='k')
# plt.axvline(x=encounter_time_7, ls='--', color='k')

#plt.legend(loc='lower left')

#plt.title('Difference in angular momentum of stars in the stream of cluster 268', size=18, fontweight='bold')

plt.savefig('Perturbations2.pdf', format='pdf', bbox_inches='tight')
plt.show()
