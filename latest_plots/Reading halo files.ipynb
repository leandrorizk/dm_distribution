# %%
import numpy as np
import astropy as ast
import scipy as sc
import matplotlib.pyplot as plt


dir = '/data/vxtest/519'

ifile = 930

haloname =  f'{dir}'+'/halos/h' + f'{ifile}'+ '.z0.000.AHF_halos'
dh = np.loadtxt(haloname)
halom = dh[:,3] #halo mass. The file also has various radii and velocities
halox = dh[:,5]
haloy = dh[:,6]
haloz = dh[:,7]
halovx = dh[:,8]
halovy = dh[:,9]
halovz = dh[:,10]

# #need to use the same xh, vxh etc for the center of mass as used for the stars
# hx = halox - xh
# hy = haloy - yh
# hz = haloz - zh
# hvx = halovx - vxh
# hvy = halovy - vyh
# hvz = halovz - vzh

# %%
for m in halom:
    print(m)
# Out:
# 686911000000.0
# 74464200000.0
# 49405900000.0
# 32998900000.0
# 31096400000.0
# 30892800000.0
# 22841500000.0
# 21751000000.0
# 12245500000.0
# 12098600000.0
# 11285100000.0
# 8786150000.0
# 6899040000.0
# 6830580000.0
# 6719300000.0
# 6090370000.0
# 6005620000.0
# 5400260000.0
# 5320080000.0
# 5235430000.0
# 4977200000.0
# 4626340000.0
# 4390170000.0
# 3719870000.0
# 3648520000.0
# 3647500000.0
# 3320810000.0
# 3280740000.0
# 3022550000.0
# 2797210000.0
# 2682910000.0
# 2587710000.0
# 2511470000.0
# 2372150000.0
# 2323010000.0
# 2260140000.0
# 2200860000.0
# 2185900000.0
# 2168070000.0
# 2074630000.0
# 2045600000.0
# 2024740000.0
# 1823360000.0
# 1803130000.0
# 1674550000.0
# 1615440000.0
# 1566540000.0
# 1531110000.0
# 1381420000.0
# 1347650000.0
# 1338850000.0
# 1274190000.0
# 1265180000.0
# 1260680000.0
# 1242980000.0
# 1215150000.0
# 1198440000.0
# 1169590000.0
# 1161400000.0
# 1149290000.0
# 1126180000.0
# 1093290000.0
# 1061480000.0
# 1024160000.0
# 1021270000.0
# ...
